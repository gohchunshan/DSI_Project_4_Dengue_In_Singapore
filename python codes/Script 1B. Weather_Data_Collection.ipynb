# %%
import requests
from bs4 import BeautifulSoup
import time
import pandas as pd
from selenium import webdriver
from bs4 import BeautifulSoup as bs
from pprint import pprint
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select
from selenium.webdriver.support.wait import WebDriverWait
from selenium.common.exceptions import NoSuchElementException, StaleElementReferenceException
from selenium.webdriver.support import expected_conditions as EC

# %%
from webdriver_manager.chrome import ChromeDriverManager

# %%
wd = webdriver.Chrome(ChromeDriverManager().install())
# Out:
# /var/folders/s9/swv_w1zd6cdfjmwpdh_tnv1r0000gn/T/ipykernel_85634/3832095755.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   wd = webdriver.Chrome(ChromeDriverManager().install())

# %%
url = 'http://www.weather.gov.sg/climate-historical-daily/'

# %%
wd.get(url)

# %%
city = wd.find_element(By.ID,'cityname')
city.click()

# %%
wd.find_element(By.LINK_TEXT, 'Admiralty').click()

# %%
month = wd.find_element(By.ID,'month')
month.click()

# %%
wd.find_element(By.LINK_TEXT, 'January').click()

# %%
wd.find_element(By.XPATH, '//*[@id="yearDiv"]').click()

# %%
wd.find_element(By.XPATH, '//*[@id="yearDiv"]/ul/li['+str(1)+']/a').click()

# %%
display = wd.find_element(By.ID,'display')
display.click()

# %%
csv = wd.find_element(By.LINK_TEXT,'CSV')
csv.click()

# %%
data_table = pd.read_html(wd.find_element(By.XPATH, '//*[@id="temp"]/h4[2]/div/div/table').get_attribute('outerHTML'))

# %%
df = data_table[0]

# %%
city_option_xpath_id = '/html/body/div/div/div[3]/div[1]/div[1]/div/div'
#         for option in range(1,64):
#             wd.find_element(By.XPATH, '/html/body/div/div/div[3]/div[1]/div[1]/div/div').click()
#             wd.find_element(By.XPATH, '/html/body/div/div/div[3]/div[1]/div[1]/div/div/ul/li['+str(option)+']/a').click()

# %%
button_dropdown_option(year_option_xpath_id,2,display_button_xpath)

# %%
def button_dropdown_option_loop(option_xpath_id, number_of_options, display_button_xpath, 
                                table_xpath, df_to_save):
    '''This function selects the button and clicks on each option in order, starting from the top.
    Diplay button is then clicked to display the table below, and saves the table as a df'''
    for option in range(1,number_of_options+1):
        driver.find_element_by_xpath(option_xpath_id).click()
        driver.find_element_by_xpath(option_xpath_id+'/ul/li['+str(option)+']/a').click()
        driver.find_element_by_xpath(display_button_xpath).click()
        time.sleep(2)
        df_to_save = get_html_table_as_df(table_xpath, df_to_save) 
        time.sleep(1)
    return df_to_save

# %%
def get_html_table_as_df(table_xpath,df_to_save):
    '''This saves a html table as a df. 
    Rmb to create an empty df to save the data to before executing this function. 
    If the df to save the data to is not empty, this function appends cases'''
    table_html = driver.find_element_by_xpath('table_xpath').get_attribute('outerHTML')
    data_table = pd.read_html(table_html)
    df = data_table[0]
    if df_to_save.empty:
        df_to_save = data_table[0]
    else: df_to_save = df_to_save.append(data_table[0])
    return df_to_save

# %%
def get_html_table_as_df(table_xpath, df_name):
    table_html = wd.find_element(By.XPATH, table_xpath).get_attribute('outerHTML')
    data_table = pd.read_html(table_html)
    df = data_table[0]
    if df_name.empty:
        df_name = data_table[0]
    else: df_name = df_to_save.append(data_table[0])
    return df_name

# %%
months = ['January','February','March','April','May','June','July',
          'August','September','October','November','December']
def get_weather(town, year):
    wd.find_element(By.ID,'cityname').click()
    wd.find_element(By.LINK_TEXT, town).click()
    for month in months:
        if year == '2022' and month == 'December':
            break
        else:
            try:
                wd.find_element(By.ID, 'year').click()
                wd.find_element(By.LINK_TEXT, year).click()
                wd.find_element(By.ID, 'month').click()
                wd.find_element(By.LINK_TEXT, month).click()        
                wd.find_element(By.ID,'display').click()
                time.sleep(2)
                wd.find_element(By.LINK_TEXT,'CSV').click()
                time.sleep(1)
            except :
                time.sleep(1)
                continue
    year = int(year)+1
    year = str(year)
    get_weather(town = town, year = year)
    
# months = ['January','February','March','April','May','June','July',
#               'August','September','October','November','December']

# wait = WebDriverWait(wd, 2)

# def get_weather(town, year):
#     # select city
#     wd.find_element(By.ID,'cityname').click()
#     wd.find_element(By.LINK_TEXT, town).click()
    
#     # select year
#     print(year)
#     try:
#         wait.until(EC.element_to_be_clickable((By.ID, 'year'))).click()
#         wait.until(EC.element_to_be_clickable((By.LINK_TEXT, year))).click()
#         # loop months options
#         for month in months:
#             # end function if condition met
#             if year == '2022' and month == 'December':
#                 return
#             else:
#                 try:
#                     wait.until(EC.element_to_be_clickable((By.ID, 'month'))).click()
#                     wait.until(EC.element_to_be_clickable((By.LINK_TEXT, month))).click()
#                     wd.find_element(By.ID,'display').click()
#                     wait.until(EC.element_to_be_clickable((By.LINK_TEXT, 'CSV'))).click()
                    
# #                     wd.find_element(By.ID, 'month').click()
# #                     wd.find_element(By.LINK_TEXT, month).click()        
# #                     wd.find_element(By.ID,'display').click()
# #                     time.sleep(2)
# #                     wd.find_element(By.LINK_TEXT,'CSV').click()
# #                     time.sleep(2)
#                 except:
#                     continue
#     except:
#         year = int(year)+1
#         year = str(year)
#         get_weather(town = town, year = year)

# %%
res = requests.get('http://www.weather.gov.sg/climate-historical-daily/')
url_content = bs(res.content, 'lxml')

# %%
ul = url_content.find('ul', {'class': 'dropdown-menu long-dropdown'})

# %%
towns = []
for li in ul.find_all('li'):
    town = {}
    town = li.text
    towns.append(town)
pd.DataFrame(towns)
# Out:
#                          0
# 0                Admiralty
# 1           Admiralty West
# 2               Ang Mo Kio
# 3          Boon Lay (East)
# 4          Boon Lay (West)
# ..                     ...
# 58              Ulu Pandan
# 59  Upper Peirce Reservoir
# 60           Upper Thomson
# 61                 Whampoa
# 62                  Yishun
#
# [63 rows x 1 columns]

# %%
towns
# Out:
# ['Admiralty',
#  'Admiralty West',
#  'Ang Mo Kio',
#  'Boon Lay (East)',
#  'Boon Lay (West)',
#  'Botanic Garden',
#  'Buangkok',
#  'Bukit Panjang',
#  'Bukit Timah',
#  'Buona Vista',
#  'Chai Chee',
#  'Changi',
#  'Choa Chu Kang (Central)',
#  'Choa Chu Kang (South)',
#  'Choa Chu Kang (West)',
#  'Clementi',
#  'Dhoby Ghaut',
#  'East Coast Parkway',
#  'Jurong (East)',
#  'Jurong (North)',
#  'Jurong (West)',
#  'Jurong Island',
#  'Jurong Pier',
#  'Kampong Bahru',
#  'Kent Ridge',
#  'Khatib',
#  'Kranji Reservoir',
#  'Lim Chu Kang',
#  'Lower Peirce Reservoir',
#  'Macritchie Reservoir',
#  'Mandai',
#  'Marina Barrage',
#  'Marine Parade',
#  'Newton',
#  'Nicoll Highway',
#  'Pasir Panjang',
#  'Pasir Ris (Central)',
#  'Pasir Ris (West)',
#  'Paya Lebar',
#  'Pulau Ubin',
#  'Punggol',
#  'Queenstown',
#  'Seletar',
#  'Semakau Island',
#  'Sembawang',
#  'Sentosa Island',
#  'Serangoon',
#  'Serangoon North',
#  'Simei',
#  'Somerset (Road)',
#  'Tai Seng',
# ...

# %%
wd = webdriver.Chrome(ChromeDriverManager().install())
url = 'http://www.weather.gov.sg/climate-historical-daily/'
wd.get(url)
# Out:
# /var/folders/s9/swv_w1zd6cdfjmwpdh_tnv1r0000gn/T/ipykernel_95532/2005840492.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   wd = webdriver.Chrome(ChromeDriverManager().install())

# %%
get_weather('Yishun','2012')
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# /var/folders/s9/swv_w1zd6cdfjmwpdh_tnv1r0000gn/T/ipykernel_95532/1186039366.py in get_weather(town, year)
#      11                 wd.find_element(By.ID, 'year').click()
# ---> 12                 wd.find_element(By.LINK_TEXT, year).click()
#      13                 wd.find_element(By.ID, 'month').click()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#     855
# --> 856         return self.execute(Command.FIND_ELEMENT, {
#     857             'using': by,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     428         if response:
# --> 429             self.error_handler.check_response(response)
#     430             response['value'] = self._unwrap_value(
#
# ...

# %%
import os
import glob
import pandas as pd

csv_files = glob.glob('../data/weather/*.{}'.format('csv'))
csv_files
# Out:
# ['../data/weather/DAILYDATA_S35_201302.csv',
#  '../data/weather/DAILYDATA_S104_201704.csv',
#  '../data/weather/DAILYDATA_S112_201205.csv',
#  '../data/weather/DAILYDATA_S106_201809.csv',
#  '../data/weather/DAILYDATA_S115_201706.csv',
#  '../data/weather/DAILYDATA_S23_201603.csv',
#  '../data/weather/DAILYDATA_S94_201901.csv',
#  '../data/weather/DAILYDATA_S114_201408.csv',
#  '../data/weather/DAILYDATA_S33_202006.csv',
#  '../data/weather/DAILYDATA_S114_202101.csv',
#  '../data/weather/DAILYDATA_S29_201505.csv',
#  '../data/weather/DAILYDATA_S29_201511.csv',
#  '../data/weather/DAILYDATA_S50_201403.csv',
#  '../data/weather/DAILYDATA_S33_202012.csv',
#  '../data/weather/DAILYDATA_S112_201211.csv',
#  '../data/weather/DAILYDATA_S40_202206.csv',
#  '../data/weather/DAILYDATA_S115_201712.csv',
#  '../data/weather/DAILYDATA_S104_201710.csv',
#  '../data/weather/DAILYDATA_S77_202206.csv',
#  '../data/weather/DAILYDATA_S122_201712.csv',
#  '../data/weather/DAILYDATA_S66_202204.csv',
# ...

# %%
df_append = pd.DataFrame()
#append all files together
for file in csv_files:
    df_temp = pd.read_csv(file, encoding='latin1')
    df_append = df_append.append(df_temp, ignore_index=True)
df_append
# Out:
#               Station    Year  Month   Day Daily Rainfall Total (mm)  \
# 0          Ulu Pandan  2013.0    2.0   1.0                      17.6
# 1          Ulu Pandan  2013.0    2.0   2.0                         0
# 2          Ulu Pandan  2013.0    2.0   3.0                      25.8
# 3          Ulu Pandan  2013.0    2.0   4.0                       0.4
# 4          Ulu Pandan  2013.0    2.0   5.0                      54.4
# ...               ...     ...    ...   ...                       ...
# 228827  Jurong Island  2018.0   12.0  27.0                       0.2
# 228828  Jurong Island  2018.0   12.0  28.0                         0
# 228829  Jurong Island  2018.0   12.0  29.0                       0.2
# 228830  Jurong Island  2018.0   12.0  30.0                         0
# 228831  Jurong Island  2018.0   12.0  31.0                       5.2
#
#        Highest 30 Min Rainfall (mm) Highest 60 Min Rainfall (mm)  \
# 0                                                             
# ...

# %%
df_append.to_csv('../data/weather.csv', index=False)
