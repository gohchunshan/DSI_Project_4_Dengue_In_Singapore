# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 4 Dengue cases in Singapore by eweeks modelling/ prediction

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# ### Contents:
# - [1. EDA](#EDA)
# - [2. Data Importing and Cleaning](#-Data-Importing-and-Cleaning)

# %% [markdown]
# ## Importing Libraries

# %%
import json

# %%
# Imports:
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
import pip
print(pip.__version__)
#$ sudo pip install --upgrade setuptools 
#pip install --upgrade pip
#python3 -m pip install --upgrade pip
# Out:
# 9.0.1

# %%
#Attempted to update pip version and install pycaret but failed
#!pip install pycaret[full]

# %% [markdown]
# ## Data Importing and Cleaning

# %% [markdown]
# #### Import Dengue data from MOH website
# MOH data gives the full number of cases of infectious diseases in the whole Singapore, which includes Dengue Fever and Dengue Haemorhagic Fever (DHF).

# %%
filepath = 'data/'

# %%
df_daily_dengue = pd.read_csv(filepath + 'moh_data.csv')

# %%
df_daily_dengue.head()
# Out:
#    id  epi_week epi_week_year    start      end  start_dd  start_mm  \
# 0   1         1      2012-W01   1/1/12   7/1/12         1         1
# 1   2         2      2012-W02   8/1/12  14/1/12         8         1
# 2   3         3      2012-W03  15/1/12  21/1/12        15         1
# 3   4         4      2012-W04  22/1/12  28/1/12        22         1
# 4   5         5      2012-W05  29/1/12   4/2/12        29         1
#
#    start_yyyy  end_dd  end_mm     ...      zika  ebola  japanese_encephalitis  \
# 0        2012       7       1     ...         0      0                      0
# 1        2012      14       1     ...         0      0                      0
# 2        2012      21       1     ...         0      0                      0
# 3        2012      28       1     ...         0      0                      0
# 4        2012       4       2     ...         0      0                      0
#
#    tetanus  botulism  murine_typhus  acute_upper_respiratory_tract_infections  \
# 0        0         0              0                                      2932
# 1        0         0              0                                      3189
# 2        0         0              0                                      3185
# 3        0         0              0                                      4001
# 4        0         0              0                                      3356
#
#    acute_conjunctivitis  acute_diarrhoea  chickenpox
# 0                   120              491          18
# 1                   114              575          19
# 2                   106              539          16
# 3                   118              615          24
# 4                   110              559          18
#
# [5 rows x 54 columns]

# %%
df_daily_dengue.shape
# Out:
# (570, 54)

# %% [markdown]
# #### Import Weather data from Singapore Meteorological Services
# This was scraped from the web using selenium and gives daily weather data from 2012 to 2020 from 63 weather stations across the country.

# %%
df_weather = pd.read_csv(filepath + 'weather_cleaned.csv')
# Out:
# C:\Users\gohch\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2728: DtypeWarning: Columns (4,5,6,7,8,9,10,11,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df_weather.shape
# Out:
# (228709, 15)

# %%
df_weather.head()
# Out:
#    Station  Year  Month  Day Daily Rainfall Total (mm)  \
# 0  Punggol  2012      1    1                       9.8
# 1  Punggol  2012      1    2                         0
# 2  Punggol  2012      1    3                         0
# 3  Punggol  2012      1    4                         0
# 4  Punggol  2012      1    5                         0
#
#   Highest 30 Min Rainfall (mm) Highest 60 Min Rainfall (mm)  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3                          NaN                          NaN
# 4                          NaN                          NaN
#
#   Highest 120 Min Rainfall (mm) Mean Temperature (°C)  \
# 0                           NaN                   NaN
# 1                           NaN                   NaN
# 2                           NaN                   NaN
# 3                           NaN                   NaN
# 4                           NaN                   NaN
#
#   Maximum Temperature (°C) Minimum Temperature (°C) Mean Wind Speed (km/h)  \
# 0                      NaN                      NaN                    NaN
# 1                      NaN                      NaN                    NaN
# 2                      NaN                      NaN                    NaN
# 3                      NaN                      NaN                    NaN
# 4                      NaN                      NaN                    NaN
#
#   Max Wind Speed (km/h)      Date   Epiweek
# 0                   NaN  1/1/2012  2012-W01
# 1                   NaN  2/1/2012  2012-W01
# 2                   NaN  3/1/2012  2012-W01
# 3                   NaN  4/1/2012  2012-W01
# 4                   NaN  5/1/2012  2012-W01

# %%
df_weather.dtypes
# Out:
# Station                          object
# Year                              int64
# Month                             int64
# Day                               int64
# Daily Rainfall Total (mm)        object
# Highest 30 Min Rainfall (mm)     object
# Highest 60 Min Rainfall (mm)     object
# Highest 120 Min Rainfall (mm)    object
# Mean Temperature (°C)            object
# Maximum Temperature (°C)         object
# Minimum Temperature (°C)         object
# Mean Wind Speed (km/h)           object
# Max Wind Speed (km/h)            object
# Date                             object
# Epiweek                          object
# dtype: object

# %%
df_weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 228709 entries, 0 to 228708
# Data columns (total 15 columns):
# Station                          228709 non-null object
# Year                             228709 non-null int64
# Month                            228709 non-null int64
# Day                              228709 non-null int64
# Daily Rainfall Total (mm)        223590 non-null object
# Highest 30 Min Rainfall (mm)     169627 non-null object
# Highest 60 Min Rainfall (mm)     169627 non-null object
# Highest 120 Min Rainfall (mm)    169627 non-null object
# Mean Temperature (°C)            106317 non-null object
# Maximum Temperature (°C)         110711 non-null object
# Minimum Temperature (°C)         110697 non-null object
# Mean Wind Speed (km/h)           112110 non-null object
# Max Wind Speed (km/h)            111638 non-null object
# Date                             228709 non-null object
# Epiweek                          228709 non-null object
# dtypes: int64(3), object(12)
# memory usage: 26.2+ MB

# %% [markdown]
# ###### Dealing with missing values in Weather dataset
# The simplest way would be to drop all the rows containing NA values, but that is not feasible as there are quite significant proportion of NA values in our data.
# We observe there is approximately 30% missing data for columns related to Rainfall (Highest 30 Min, 60 Min and 120 Min Rainfall), and 60% missing data for columns related to Temperature (Mean, Max and Min Temperatures), and also 60% missing data for Wind speed columns (Mean Wind Speed (km/h), Max Wind Speed (km/h)).
#
# ###### Method for imputing NA values
# - Rainfall: Take the mean of all the other values within the same year, month and Station. However, we note that there is no Rainfall data at all for 2012 - 2013, hence this is only possible for the year 2014 onwards.
# - Temperature/ Wind Speed: Take the mean value of all other values within the same year, month and Station as well, so that the monthly averages are not affected. There may be higher number of NA's left after imputing as there are < 50% non-null values in these columns

# %% [markdown]
# First, we need to ensure that data types are float instead of string

# %%
columnlist_tofloat = ['Daily Rainfall Total (mm)', 'Highest 30 Min Rainfall (mm)', 'Highest 60 Min Rainfall (mm)', 
              'Highest 120 Min Rainfall (mm)', 'Mean Temperature (°C)', 'Maximum Temperature (°C)',
             'Minimum Temperature (°C)', 'Mean Wind Speed (km/h)', 'Max Wind Speed (km/h)']

# %%
for column in columnlist_tofloat:
    df_weather[column] = df_weather[column].apply(lambda x: float(x) if x!='-' else np.nan)

# %%
df_weather.dtypes
# Out:
# Station                           object
# Year                               int64
# Month                              int64
# Day                                int64
# Daily Rainfall Total (mm)        float64
# Highest 30 Min Rainfall (mm)     float64
# Highest 60 Min Rainfall (mm)     float64
# Highest 120 Min Rainfall (mm)    float64
# Mean Temperature (°C)            float64
# Maximum Temperature (°C)         float64
# Minimum Temperature (°C)         float64
# Mean Wind Speed (km/h)           float64
# Max Wind Speed (km/h)            float64
# Date                              object
# Epiweek                           object
# dtype: object

# %%
df_weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 228709 entries, 0 to 228708
# Data columns (total 15 columns):
# Station                          228709 non-null object
# Year                             228709 non-null int64
# Month                            228709 non-null int64
# Day                              228709 non-null int64
# Daily Rainfall Total (mm)        226131 non-null float64
# Highest 30 Min Rainfall (mm)     171833 non-null float64
# Highest 60 Min Rainfall (mm)     171833 non-null float64
# Highest 120 Min Rainfall (mm)    171833 non-null float64
# Mean Temperature (°C)            75358 non-null float64
# Maximum Temperature (°C)         80777 non-null float64
# Minimum Temperature (°C)         80777 non-null float64
# Mean Wind Speed (km/h)           80378 non-null float64
# Max Wind Speed (km/h)            81322 non-null float64
# Date                             228709 non-null object
# Epiweek                          228709 non-null object
# dtypes: float64(9), int64(3), object(3)
# memory usage: 26.2+ MB

# %%
#Rename those long headers to shorter ones for ease of calling
df_weather.rename(columns={"Daily Rainfall Total (mm)": "total_rainfall", 
                            "Highest 30 Min Rainfall (mm)": "rainfall_30min",
                            "Highest 60 Min Rainfall (mm)": "rainfall_60min",
                            "Highest 120 Min Rainfall (mm)": "rainfall_120min",
                            "Mean Temperature (°C)": "temperature_mean",
                            "Maximum Temperature (°C)": "temperature_max",
                            "Minimum Temperature (°C)": "temperature_min",
                            "Mean Wind Speed (km/h)": "windspeed_mean",
                            "Max Wind Speed (km/h)": "windspeed_max"
                           }, inplace = True)

# %%
df_weather.info() #Before imputing
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 228709 entries, 0 to 228708
# Data columns (total 15 columns):
# Station             228709 non-null object
# Year                228709 non-null int64
# Month               228709 non-null int64
# Day                 228709 non-null int64
# total_rainfall      226131 non-null float64
# rainfall_30min      171833 non-null float64
# rainfall_60min      171833 non-null float64
# rainfall_120min     171833 non-null float64
# temperature_mean    75358 non-null float64
# temperature_max     80777 non-null float64
# temperature_min     80777 non-null float64
# windspeed_mean      80378 non-null float64
# windspeed_max       81322 non-null float64
# Date                228709 non-null object
# Epiweek             228709 non-null object
# dtypes: float64(9), int64(3), object(3)
# memory usage: 26.2+ MB

# %%
columnlist = ["total_rainfall",  "rainfall_30min", "rainfall_60min", "rainfall_120min",
             "temperature_mean", "temperature_max", "temperature_min", 
              "windspeed_mean", "windspeed_max"]

# %%
for column in columnlist:
    df_weather[column] = df_weather.groupby(['Station','Year','Month'])[column].transform(lambda x: x.fillna(x.mean()))

# %%
df_weather.info() #After imputing
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 228709 entries, 0 to 228708
# Data columns (total 15 columns):
# Station             228709 non-null object
# Year                228709 non-null int64
# Month               228709 non-null int64
# Day                 228709 non-null int64
# total_rainfall      226131 non-null float64
# rainfall_30min      171833 non-null float64
# rainfall_60min      171833 non-null float64
# rainfall_120min     171833 non-null float64
# temperature_mean    75358 non-null float64
# temperature_max     80777 non-null float64
# temperature_min     80777 non-null float64
# windspeed_mean      80378 non-null float64
# windspeed_max       81322 non-null float64
# Date                228709 non-null object
# Epiweek             228709 non-null object
# dtypes: float64(9), int64(3), object(3)
# memory usage: 26.2+ MB

# %% [markdown]
# As there are many other null values to be imputed, we will do a second round of imputation by using the mean of the similar months from other years.

# %%
for column in columnlist:
    df_weather[column] = df_weather.groupby(['Station','Month'])[column].transform(lambda x: x.fillna(x.mean()))

# %%
df_weather.info() #After second round of imputing
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 228709 entries, 0 to 228708
# Data columns (total 15 columns):
# Station             228709 non-null object
# Year                228709 non-null int64
# Month               228709 non-null int64
# Day                 228709 non-null int64
# total_rainfall      228709 non-null float64
# rainfall_30min      228525 non-null float64
# rainfall_60min      228525 non-null float64
# rainfall_120min     228525 non-null float64
# temperature_mean    84240 non-null float64
# temperature_max     84240 non-null float64
# temperature_min     84240 non-null float64
# windspeed_mean      84240 non-null float64
# windspeed_max       84240 non-null float64
# Date                228709 non-null object
# Epiweek             228709 non-null object
# dtypes: float64(9), int64(3), object(3)
# memory usage: 26.2+ MB

# %% [markdown]
# Rainfall seems to be almost 100% imputed, temperature and windspeed are still less than 50% non-NA. For the rest, we will fill with the global mean.

# %%
df_weather[columnlist] = df_weather[columnlist].fillna(df_weather[columnlist].mean())

# %%
df_weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 228709 entries, 0 to 228708
# Data columns (total 15 columns):
# Station             228709 non-null object
# Year                228709 non-null int64
# Month               228709 non-null int64
# Day                 228709 non-null int64
# total_rainfall      228709 non-null float64
# rainfall_30min      228709 non-null float64
# rainfall_60min      228709 non-null float64
# rainfall_120min     228709 non-null float64
# temperature_mean    228709 non-null float64
# temperature_max     228709 non-null float64
# temperature_min     228709 non-null float64
# windspeed_mean      228709 non-null float64
# windspeed_max       228709 non-null float64
# Date                228709 non-null object
# Epiweek             228709 non-null object
# dtypes: float64(9), int64(3), object(3)
# memory usage: 26.2+ MB

# %% [markdown]
# Finally, we have all the missing values imputed.

# %% [markdown]
# #### Import the NEA dengue cases data
#
# This data reflects cases within clusters (defined as at least 2 reported dengue cases) in each geographical region in Singapore. The time period of the data scraped is mid-2013 to 2020. There are 39 unique regions in this dataframe.

# %%
df_cases_bylocations = pd.read_csv(filepath + 'final_location_based_data.csv')

# %%
df_cases_bylocations.head()
# Out:
#   epi_week_year      start        end     actual  ang mo kio  bedok  bishan  \
# 0      2013-W21  19/5/2013  25/5/2013  23/5/2013         0.0   63.0     5.0
# 1      2013-W22  26/5/2013   1/6/2013  27/5/2013         0.0   63.0     8.0
# 2      2013-W23   2/6/2013   8/6/2013        NaN         NaN    NaN     NaN
# 3      2013-W24   9/6/2013  15/6/2013  11/6/2013        23.0   30.0     0.0
# 4      2013-W25  16/6/2013  22/6/2013  17/6/2013        11.0   28.0     7.0
#
#    boon lay  bukit batok  bukit merah   ...    sentosa  serangoon  \
# 0       4.0          3.0          0.0   ...        0.0       10.0
# 1       4.0          3.0          2.0   ...        0.0        9.0
# 2       NaN          NaN          NaN   ...        NaN        NaN
# 3       4.0          6.0          0.0   ...        0.0        8.0
# 4       4.0          4.0          8.0   ...        0.0       17.0
#
#    sungei kadut  tampines  tanglin  tengah  toa payoh  tuas  woodlands  yishun
# 0           0.0     203.0      0.0     0.0       15.0   0.0        3.0    81.0
# 1           0.0     193.0      2.0     0.0       16.0   0.0        4.0    81.0
# 2           NaN       NaN      NaN     NaN        NaN   NaN        NaN     NaN
# 3           0.0     297.0      1.0     0.0        9.0   0.0        4.0   126.0
# 4           0.0     325.0      5.0     0.0        7.0   0.0        0.0   145.0
#
# [5 rows x 43 columns]

# %% [markdown]
# The next step changes the column headers for the geographical regionss to rows - one row for each town

# %%
list_ = []
for region in list_regions:
    df_temp = pd.melt(df_cases_bylocations, 
                          id_vars =['epi_week_year', 'start', 'end', 'actual'], 
                          value_vars = region)
    list_.append(df_temp)

df_total_dengue_cases = pd.concat(list_, ignore_index = True)

# %%
df_total_dengue_cases.info() #There are null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19422 entries, 0 to 19421
# Data columns (total 6 columns):
# epi_week_year    15210 non-null object
# start            15210 non-null object
# end              15210 non-null object
# actual           12285 non-null object
# variable         19422 non-null object
# value            12441 non-null float64
# dtypes: float64(1), object(5)
# memory usage: 910.5+ KB

# %%
df_total_dengue_cases.columns = ['epi_week_year','start', 'end', 'actual', 'town', 'dengue_cases']

# %%
df_total_dengue_cases.head()
# Out:
#   epi_week_year      start        end     actual        town  dengue_cases
# 0      2013-W21  19/5/2013  25/5/2013  23/5/2013  ang mo kio           0.0
# 1      2013-W22  26/5/2013   1/6/2013  27/5/2013  ang mo kio           0.0
# 2      2013-W23   2/6/2013   8/6/2013        NaN  ang mo kio           NaN
# 3      2013-W24   9/6/2013  15/6/2013  11/6/2013  ang mo kio          23.0
# 4      2013-W25  16/6/2013  22/6/2013  17/6/2013  ang mo kio          11.0

# %%
df_total_dengue_cases.dtypes
# Out:
# epi_week_year     object
# start             object
# end               object
# actual            object
# town              object
# dengue_cases     float64
# dtype: object

# %% [markdown]
# ##### Dealing with null values
# Impute all NaN values with backfill method.

# %%
df_total_dengue_cases = df_total_dengue_cases.bfill(axis ='rows')

# %%
df_total_dengue_cases.shape
# Out:
# (19422, 6)

# %%
df_total_dengue_cases.info() #The null values are mostly fixed with the back fill method.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19422 entries, 0 to 19421
# Data columns (total 6 columns):
# epi_week_year    19314 non-null object
# start            19314 non-null object
# end              19314 non-null object
# actual           19314 non-null object
# town             19422 non-null object
# dengue_cases     19314 non-null float64
# dtypes: float64(1), object(5)
# memory usage: 910.5+ KB

# %% [markdown]
# Observing number of null values - these 108 values should be removed as they are meaningless to keep; only the 'town' value is filled up and the rest are NA values

# %%
#drop the null values
df_total_dengue_cases = df_total_dengue_cases.dropna()
df_total_dengue_cases.shape
# Out:
# (19314, 6)

# %%
df_total_dengue_cases.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19314 entries, 0 to 19313
# Data columns (total 6 columns):
# epi_week_year    19314 non-null object
# start            19314 non-null object
# end              19314 non-null object
# actual           19314 non-null object
# town             19314 non-null object
# dengue_cases     19314 non-null float64
# dtypes: float64(1), object(5)
# memory usage: 1.0+ MB

# %% [markdown]
# #### Checkpoint
#
# So far, we have 2 main dataframes, the `Weather` dataframe and `Total Dengue cases` dataframe. Since the `Station` column in the `Weather` dataframe and the `town` in the `Total Dengue cases` dataframe contain different list of values, we need to match the geographic regions in order to merge into one dataframe.
#
# There are 2 ways to proceed:
#
#
# 1) One way is to split the whole of Singapore into broad regions i.e. North, South, East, West, Central.
# - Every `town` in `Total Dengue cases` and every `Station` in `Weather` is matched to a broad region (North/South/west etc)
# - Then, we will aggregate the values for each broad region to create the final dataset
# - We can fit one model on all the regions represented (whole of SG), or run sub-models for each region
#
# 2) Another way (*preferred***) is to look through the list of Weather Stations and Towns, and create a lookup list to be used for merging the dataframes. This allows us to keep more granular data to have more rows of data for the eventual model.
# - As there may be a case where weather stations are in regions where no dengue cluster was reported, or vice versa (dengue cases are reported in places where there was no weather station), we will take only the intersection of the 2 lists of locations.
# - Also, there could be cases of many-to-one matching between the 2 lists of locations, for e.g. Tuas, Tuas South and Tuas West stations are all part of 'Tuas' region in the list of towns for theTotal Dengue Cases dataframe. We will deal with this in later steps

# %%
list_regions= list(df_cases_bylocations.columns) 
#Can also use the df_total_dengue_cases and find unique entries in the column for town
del list_regions[0:4]
print(list_regions)
print('\n Length:  ' + str(len(list_regions)))
# Out:
# ['ang mo kio', 'bedok', 'bishan', 'boon lay', 'bukit batok', 'bukit merah', 'bukit panjang', 'bukit timah', 'changi', 'choa chu kang', 'city', 'clementi', 'geylang', 'hougang', 'jurong east', 'jurong island', 'jurong west', 'kallang', 'lim chu kang', 'mandai', 'marine parade', 'novena', 'pasir ris', 'paya lebar', 'punggol', 'queenstown', 'seletar', 'sembawang', 'sengkang', 'sentosa', 'serangoon', 'sungei kadut', 'tampines', 'tanglin', 'tengah', 'toa payoh', 'tuas', 'woodlands', 'yishun']
#
#  Length:  39

# %%
list_weatherstations = list(set(df_weather['Station']))
print(list_weatherstations)
print('\n Length:  ' + str(len(list_weatherstations)))
# Out:
# ['Pasir Ris (Central)', 'Buangkok', 'Choa Chu Kang (Central)', 'Choa Chu Kang (West)', 'Queenstown', 'Chai Chee', 'Bukit Timah', 'Tuas West', 'Marina Barrage', 'Admiralty', 'Jurong Pier', 'Marine Parade', 'Somerset (Road)', 'Whampoa', 'Pasir Panjang', 'Khatib', 'Buona Vista', 'Tanjong Katong', 'Newton', 'Jurong Island', 'Pasir Ris (West)', 'Toa Payoh', 'Tuas South', 'Boon Lay (East)', 'Upper Peirce Reservoir', 'Semakau Island', 'Sentosa Island', 'Choa Chu Kang (South)', 'Tengah', 'Lower Peirce Reservoir', 'Lim Chu Kang', 'Nicoll Highway', 'Botanic Garden', 'Sembawang', 'Admiralty West', 'Clementi', 'East Coast Parkway', 'Simei', 'Yishun', 'Kent Ridge', 'Tuas', 'Tai Seng', 'Ang Mo Kio', 'Bukit Panjang', 'Kranji Reservoir', 'Jurong (West)', 'Mandai', 'Seletar', 'Macritchie Reservoir', 'Paya Lebar', 'Serangoon North', 'Jurong (East)', 'Tanjong Pagar', 'Kampong Bahru', 'Punggol', 'Serangoon', 'Dhoby Ghaut', 'Upper Thomson', 'Changi', 'Pulau Ubin', 'Boon Lay (West)', 'Jurong (North)', 'Ulu Pandan']
#
#  Length:  63

# %%
df_total_dengue_cases.groupby('town').mean()
# Out:
#                dengue_cases
# town
# ang mo kio        45.991968
# bedok             69.000000
# bishan            22.626506
# boon lay           1.718876
# bukit batok        9.636546
# bukit merah        3.865462
# bukit panjang     21.558233
# bukit timah       10.018072
# changi            12.000000
# choa chu kang     28.014056
# city               9.819277
# clementi           8.767068
# geylang           59.407631
# hougang           42.688755
# jurong east        4.831325
# jurong island      9.329317
# jurong west       22.973896
# kallang           36.283133
# lim chu kang       0.006024
# mandai             0.126506
# marine parade     50.265060
# novena            11.064257
# pasir ris         22.933735
# paya lebar         0.831325
# punggol            5.580321
# queenstown         6.120482
# seletar           11.542169
# sembawang          6.226908
# sengkang           6.026104
# sentosa            2.451807
# serangoon         28.311245
# sungei kadut      44.279116
# tampines          34.626506
# tanglin           15.248996
# tengah             3.253012
# toa payoh         29.957831
# tuas               0.759036
# woodlands         41.993976
# yishun            22.056410

# %% [markdown]
# Note to self:EDA this to show the town with largest number of dengue incidences over the year. Also can split by years

# %%
df_weather.groupby('Station').mean()
# Out:
#                                 Year     Month        Day  \
# Station
# Admiralty                2016.982815  6.460955  15.730099
# Admiralty West           2015.332928  6.353609  15.732360
# Ang Mo Kio               2016.960371  6.480060  15.728367
# Boon Lay (East)          2013.550938  6.408177  15.735255
# Boon Lay (West)          2014.637599  6.438650  15.724803
# Botanic Garden           2016.960371  6.480060  15.728367
# Buangkok                 2015.178558  6.342174  15.721703
# Bukit Panjang            2016.915500  6.509544  15.738865
# Bukit Timah              2017.038561  6.399845  15.723602
# Buona Vista              2017.015032  6.566624  15.724076
# Chai Chee                2016.967652  6.460955  15.730099
# Changi                   2016.960371  6.480060  15.728367
# Choa Chu Kang (Central)  2016.960371  6.480060  15.728367
# Choa Chu Kang (South)    2016.975733  6.491658  15.726239
# Choa Chu Kang (West)     2016.461071  6.475428  15.729155
# Clementi                 2016.960371  6.480060  15.728367
# Dhoby Ghaut              2016.967652  6.460955  15.730099
# East Coast Parkway       2016.960371  6.480060  15.728367
# Jurong (East)            2012.907371  6.111554  15.723108
# Jurong (North)           2015.192366  6.334467  15.718443
# Jurong (West)            2017.103602  6.334210  15.723113
# Jurong Island            2016.960371  6.480060  15.728367
# Jurong Pier              2016.960371  6.480060  15.728367
# Kampong Bahru            2013.930917  6.348811  15.734428
# Kent Ridge               2016.960371  6.480060  15.728367
# Khatib                   2016.499589  6.522310  15.731454
# Kranji Reservoir         2016.967652  6.460955  15.730099
# Lim Chu Kang             2016.982680  6.488283  15.727967
# Lower Peirce Reservoir   2016.975096  6.460334  15.725802
# Macritchie Reservoir     2016.960371  6.480060  15.728367
# ...                              ...       ...        ...
# Newton                   2016.982803  6.397844  15.729723
# Nicoll Highway           2016.960371  6.480060  15.728367
# Pasir Panjang            2016.960371  6.480060  15.728367
# Pasir Ris (Central)      2016.967652  6.460955  15.730099
# Pasir Ris (West)         2016.967897  6.452477  15.726239
# Paya Lebar               2016.960371  6.480060  15.728367
# Pulau Ubin               2017.068011  6.477114  15.734678
# Punggol                  2016.960371  6.480060  15.728367
# Queenstown               2016.960371  6.480060  15.728367
# Seletar                  2016.960371  6.480060  15.728367
# Semakau Island           2016.987203  6.476365  15.736746
# Sembawang                2016.960371  6.480060  15.728367
# Sentosa Island           2016.967897  6.436805  15.726239
# Serangoon                2016.960371  6.480060  15.728367
# Serangoon North          2014.156495  6.277517  15.725613
# Simei                    2016.983055  6.444416  15.725802
# Somerset (Road)          2016.960371  6.480060  15.728367
# Tai Seng                 2016.960371  6.480060  15.728367
# Tanjong Katong           2016.960371  6.480060  15.728367
# Tanjong Pagar            2013.466434  6.404196  15.723776
# Tengah                   2016.960371  6.480060  15.728367
# Toa Payoh                2016.960371  6.480060  15.728367
# Tuas                     2017.022160  6.433011  15.727967
# Tuas South               2016.960371  6.480060  15.728367
# Tuas West                2017.066004  6.476664  15.725490
# Ulu Pandan               2016.960371  6.480060  15.728367
# Upper Peirce Reservoir   2016.960371  6.480060  15.728367
# Upper Thomson            2016.056569  6.521898  15.732664
# Whampoa                  2016.960371  6.480060  15.728367
# Yishun                   2016.263872  6.399578  15.722256
#
#                          Daily Rainfall Total (mm)  \
# Station
# Admiralty                                 6.602496
# Admiralty West                            6.761546
# Ang Mo Kio                                6.973208
# Boon Lay (East)                           6.810597
# Boon Lay (West)                           7.250013
# Botanic Garden                            7.069547
# Buangkok                                  6.347924
# Bukit Panjang                             7.499011
# Bukit Timah                               6.927721
# Buona Vista                               6.723895
# Chai Chee                                 5.832654
# Changi                                    5.389742
# Choa Chu Kang (Central)                   7.151256
# Choa Chu Kang (South)                     7.141866
# Choa Chu Kang (West)                      6.884899
# Clementi                                  7.045972
# Dhoby Ghaut                               6.434824
# East Coast Parkway                        4.878124
# Jurong (East)                             7.681046
# Jurong (North)                            7.346458
# Jurong (West)                             7.287877
# Jurong Island                             6.154846
# Jurong Pier                               7.582757
# Kampong Bahru                             6.452831
# Kent Ridge                                7.069270
# Khatib                                    6.796919
# Kranji Reservoir                          6.882120
# Lim Chu Kang                              6.457189
# Lower Peirce Reservoir                    7.373910
# Macritchie Reservoir                      6.928204
# ...                                            ...
# Newton                                    6.374078
# Nicoll Highway                            6.439739
# Pasir Panjang                             6.087527
# Pasir Ris (Central)                       5.872439
# Pasir Ris (West)                          5.610291
# Paya Lebar                                6.833956
# Pulau Ubin                                5.769858
# Punggol                                   6.448713
# Queenstown                                6.531802
# Seletar                                   7.101353
# Semakau Island                            5.537159
# Sembawang                                 7.434763
# Sentosa Island                            6.113318
# Serangoon                                 6.100826
# Serangoon North                           6.349893
# Simei                                     5.796404
# Somerset (Road)                           6.155986
# Tai Seng                                  6.616372
# Tanjong Katong                            5.843605
# Tanjong Pagar                             5.869218
# Tengah                                    7.587934
# Toa Payoh                                 6.865281
# Tuas                                      7.221468
# Tuas South                                6.688543
# Tuas West                                 6.670378
# Ulu Pandan                                7.104777
# Upper Peirce Reservoir                    7.246118
# Upper Thomson                             6.417892
# Whampoa                                   6.673474
# Yishun                                    6.623849
#
#                          Highest 30 Min Rainfall (mm)  \
# Station
# Admiralty                                    3.917510
# Admiralty West                               3.871831
# Ang Mo Kio                                   4.105938
# Boon Lay (East)                              3.829969
# Boon Lay (West)                              4.082140
# Botanic Garden                               4.069380
# Buangkok                                     3.729590
# Bukit Panjang                                4.363689
# Bukit Timah                                  4.031759
# Buona Vista                                  3.908669
# Chai Chee                                    3.514821
# Changi                                       3.143936
# Choa Chu Kang (Central)                      4.245945
# Choa Chu Kang (South)                        4.199056
# Choa Chu Kang (West)                         4.083460
# Clementi                                     4.121299
# Dhoby Ghaut                                  3.832366
# East Coast Parkway                           2.966264
# Jurong (East)                                3.785833
# Jurong (North)                               4.381073
# Jurong (West)                                4.291023
# Jurong Island                                3.605704
# Jurong Pier                                  4.413456
# Kampong Bahru                                3.752617
# Kent Ridge                                   4.101594
# Khatib                                       3.931611
# Kranji Reservoir                             4.200752
# Lim Chu Kang                                 3.945040
# Lower Peirce Reservoir                       4.352080
# Macritchie Reservoir                         4.030568
# ...                                               ...
# Newton                                       3.745339
# Nicoll Highway                               3.844057
# Pasir Panjang                                3.528311
# Pasir Ris (Central)                          3.423253
# Pasir Ris (West)                             3.397123
# Paya Lebar                                   3.920480
# Pulau Ubin                                   3.482125
# Punggol                                      3.809699
# Queenstown                                   3.812266
# Seletar                                      4.092236
# Semakau Island                               3.389755
# Sembawang                                    4.084560
# Sentosa Island                               3.602052
# Serangoon                                    3.655662
# Serangoon North                              3.706814
# Simei                                        3.450064
# Somerset (Road)                              3.666780
# Tai Seng                                     3.825713
# Tanjong Katong                               3.495109
# Tanjong Pagar                                3.577370
# Tengah                                       4.069181
# Toa Payoh                                    3.994740
# Tuas                                         4.276557
# Tuas South                                   3.915425
# Tuas West                                    3.967308
# Ulu Pandan                                   4.186351
# Upper Peirce Reservoir                       4.283098
# Upper Thomson                                3.765347
# Whampoa                                      3.921606
# Yishun                                       3.894077
#
#                          Highest 60 Min Rainfall (mm)  \
# Station
# Admiralty                                    4.856451
# Admiralty West                               4.801983
# Ang Mo Kio                                   5.082411
# Boon Lay (East)                              4.773418
# Boon Lay (West)                              5.103282
# Botanic Garden                               5.079688
# Buangkok                                     4.572921
# Bukit Panjang                                5.428881
# Bukit Timah                                  4.979245
# Buona Vista                                  4.870545
# Chai Chee                                    4.387561
# Changi                                       3.884088
# Choa Chu Kang (Central)                      5.266593
# Choa Chu Kang (South)                        5.235927
# Choa Chu Kang (West)                         5.137706
# Clementi                                     5.108415
# Dhoby Ghaut                                  4.721715
# East Coast Parkway                           3.710410
# Jurong (East)                                4.726888
# Jurong (North)                               5.386305
# Jurong (West)                                5.375338
# Jurong Island                                4.524153
# Jurong Pier                                  5.531301
# Kampong Bahru                                4.656326
# Kent Ridge                                   5.091418
# Khatib                                       4.849170
# Kranji Reservoir                             5.181217
# Lim Chu Kang                                 4.883627
# Lower Peirce Reservoir                       5.360863
# Macritchie Reservoir                         4.969587
# ...                                               ...
# Newton                                       4.615627
# Nicoll Highway                               4.767397
# Pasir Panjang                                4.420819
# Pasir Ris (Central)                          4.248787
# Pasir Ris (West)                             4.169530
# Paya Lebar                                   4.902188
# Pulau Ubin                                   4.279425
# Punggol                                      4.725602
# Queenstown                                   4.743717
# Seletar                                      5.082332
# Semakau Island                               4.216343
# Sembawang                                    5.086361
# Sentosa Island                               4.483081
# Serangoon                                    4.506908
# Serangoon North                              4.553130
# Simei                                        4.284375
# Somerset (Road)                              4.540380
# Tai Seng                                     4.761077
# Tanjong Katong                               4.329831
# Tanjong Pagar                                4.402566
# Tengah                                       5.090233
# Toa Payoh                                    4.939511
# Tuas                                         5.373223
# Tuas South                                   4.927870
# Tuas West                                    4.962465
# Ulu Pandan                                   5.186797
# Upper Peirce Reservoir                       5.299011
# Upper Thomson                                4.631690
# Whampoa                                      4.834248
# Yishun                                       4.819265
#
#                          Highest 120 Min Rainfall (mm)  Mean Temperature (°C)  \
# Station
# Admiralty                                     5.495392              27.695499
# Admiralty West                                5.419593              27.956304
# Ang Mo Kio                                    5.736634              27.875805
# Boon Lay (East)                               5.433043              28.234200
# Boon Lay (West)                               5.880026              27.956304
# Botanic Garden                                5.806557              27.956304
# Buangkok                                      5.121188              27.956304
# Bukit Panjang                                 6.149424              27.956304
# Bukit Timah                                   5.681313              27.956304
# Buona Vista                                   5.557617              27.956304
# Chai Chee                                     4.939199              27.956304
# Changi                                        4.401487              27.976474
# Choa Chu Kang (Central)                       5.964696              27.956304
# Choa Chu Kang (South)                         5.953298              27.706962
# Choa Chu Kang (West)                          5.848395              27.956304
# Clementi                                      5.778883              27.673273
# Dhoby Ghaut                                   5.346032              27.956304
# East Coast Parkway                            4.233877              28.140501
# Jurong (East)                                 5.347747              27.956304
# Jurong (North)                                6.069461              27.956304
# Jurong (West)                                 6.185826              27.469866
# Jurong Island                                 5.211548              28.308571
# Jurong Pier                                   6.293439              27.956304
# Kampong Bahru                                 5.276887              27.956304
# Kent Ridge                                    5.812665              27.956304
# Khatib                                        5.474833              27.652639
# Kranji Reservoir                              5.829406              27.956304
# Lim Chu Kang                                  5.513991              27.956304
# Lower Peirce Reservoir                        6.075066              27.956304
# Macritchie Reservoir                          5.629391              27.956304
# ...                                                ...                    ...
# Newton                                        5.243684              27.663723
# Nicoll Highway                                5.388361              27.956304
# Pasir Panjang                                 5.050274              28.308716
# Pasir Ris (Central)                           4.834092              27.956304
# Pasir Ris (West)                              4.702954              27.956304
# Paya Lebar                                    5.580421              28.209511
# Pulau Ubin                                    4.842113              27.423473
# Punggol                                       5.350153              27.956304
# Queenstown                                    5.396486              27.956304
# Seletar                                       5.765746              28.034856
# Semakau Island                                4.811467              28.138810
# Sembawang                                     5.796385              27.657225
# Sentosa Island                                5.128247              28.154124
# Serangoon                                     5.044397              27.956304
# Serangoon North                               5.069069              27.956304
# Simei                                         4.855355              27.956304
# Somerset (Road)                               5.146266              27.956304
# Tai Seng                                      5.408388              28.426441
# Tanjong Katong                                4.914208              27.956304
# Tanjong Pagar                                 4.990705              27.956304
# Tengah                                        5.801310              27.726666
# Toa Payoh                                     5.593854              27.956304
# Tuas                                          6.122225              27.956304
# Tuas South                                    5.609799              28.197229
# Tuas West                                     5.658345              27.956304
# Ulu Pandan                                    5.862632              27.956304
# Upper Peirce Reservoir                        5.983412              27.956304
# Upper Thomson                                 5.201079              27.956304
# Whampoa                                       5.441046              27.956304
# Yishun                                        5.453196              27.956304
#
#                          Maximum Temperature (°C)  Minimum Temperature (°C)  \
# Station
# Admiralty                               31.860829                 24.998532
# Admiralty West                          31.731324                 25.273941
# Ang Mo Kio                              31.909057                 25.139080
# Boon Lay (East)                         31.953838                 25.538458
# Boon Lay (West)                         31.731324                 25.273941
# Botanic Garden                          31.731324                 25.273941
# Buangkok                                31.731324                 25.273941
# Bukit Panjang                           31.731324                 25.273941
# Bukit Timah                             31.731324                 25.273941
# Buona Vista                             31.731324                 25.273941
# Chai Chee                               31.731324                 25.273941
# Changi                                  31.637121                 25.389165
# Choa Chu Kang (Central)                 31.731324                 25.273941
# Choa Chu Kang (South)                   31.998003                 24.852562
# Choa Chu Kang (West)                    31.731324                 25.273941
# Clementi                                31.696009                 24.989144
# Dhoby Ghaut                             31.731324                 25.273941
# East Coast Parkway                      30.360919                 26.018888
# Jurong (East)                           31.731324                 25.273941
# Jurong (North)                          31.731324                 25.273941
# Jurong (West)                           31.531714                 24.725370
# Jurong Island                           31.495800                 25.821175
# Jurong Pier                             31.731324                 25.273941
# Kampong Bahru                           31.731324                 25.273941
# Kent Ridge                              31.731324                 25.273941
# Khatib                                  32.233381                 24.666968
# Kranji Reservoir                        31.731324                 25.273941
# Lim Chu Kang                            31.731324                 25.273941
# Lower Peirce Reservoir                  31.731324                 25.273941
# Macritchie Reservoir                    31.731324                 25.273941
# ...                                           ...                       ...
# Newton                                  31.464574                 25.217729
# Nicoll Highway                          31.731324                 25.273941
# Pasir Panjang                           31.114218                 25.995371
# Pasir Ris (Central)                     31.731324                 25.273941
# Pasir Ris (West)                        31.731324                 25.273941
# Paya Lebar                              32.371791                 25.474466
# Pulau Ubin                              32.043469                 24.602270
# Punggol                                 31.731324                 25.273941
# Queenstown                              31.731324                 25.273941
# Seletar                                 32.186028                 25.246636
# Semakau Island                          30.924723                 25.859104
# Sembawang                               32.004789                 24.189330
# Sentosa Island                          31.610620                 25.693403
# Serangoon                               31.731324                 25.273941
# Serangoon North                         31.731324                 25.273941
# Simei                                   31.731324                 25.273941
# Somerset (Road)                         31.731324                 25.273941
# Tai Seng                                31.907636                 25.942090
# Tanjong Katong                          31.731324                 25.273941
# Tanjong Pagar                           31.731324                 25.273941
# Tengah                                  32.359574                 24.082369
# Toa Payoh                               31.731324                 25.273941
# Tuas                                    31.731324                 25.273941
# Tuas South                              31.283286                 25.796259
# Tuas West                               31.731324                 25.273941
# Ulu Pandan                              31.731324                 25.273941
# Upper Peirce Reservoir                  31.731324                 25.273941
# Upper Thomson                           31.731324                 25.273941
# Whampoa                                 31.731324                 25.273941
# Yishun                                  31.731324                 25.273941
#
#                          Mean Wind Speed (km/h)  Max Wind Speed (km/h)
# Station
# Admiralty                              9.346864              35.615155
# Admiralty West                         8.268342              32.607178
# Ang Mo Kio                             6.912080              31.434742
# Boon Lay (East)                        7.010409              32.420065
# Boon Lay (West)                        8.268342              32.607178
# Botanic Garden                         8.268342              32.607178
# Buangkok                               8.268342              32.607178
# Bukit Panjang                          8.268342              32.607178
# Bukit Timah                            8.268342              32.607178
# Buona Vista                            8.268342              32.607178
# Chai Chee                              8.268342              32.607178
# Changi                                 8.684511              32.575372
# Choa Chu Kang (Central)                8.268342              32.607178
# Choa Chu Kang (South)                  6.468806              30.080235
# Choa Chu Kang (West)                   8.268342              32.607178
# Clementi                               5.910642              29.080824
# Dhoby Ghaut                            8.268342              32.607178
# East Coast Parkway                    11.110194              37.260370
# Jurong (East)                          8.268342              32.607178
# Jurong (North)                         8.268342              32.607178
# Jurong (West)                          7.101039              31.379502
# Jurong Island                          8.463988              34.404170
# Jurong Pier                            8.268342              32.607178
# Kampong Bahru                          8.268342              32.607178
# Kent Ridge                             8.268342              32.607178
# Khatib                                 5.525024              27.570443
# Kranji Reservoir                       8.268342              32.607178
# Lim Chu Kang                           8.268342              32.607178
# Lower Peirce Reservoir                 8.268342              32.607178
# Macritchie Reservoir                   8.268342              32.607178
# ...                                         ...                    ...
# Newton                                 7.266967              35.343011
# Nicoll Highway                         8.268342              32.607178
# Pasir Panjang                         11.023305              38.732002
# Pasir Ris (Central)                    8.268342              32.607178
# Pasir Ris (West)                       8.268342              32.607178
# Paya Lebar                             9.724701              32.244149
# Pulau Ubin                             6.900167              28.574035
# Punggol                                8.268342              32.607178
# Queenstown                             8.268342              32.607178
# Seletar                                9.816150              35.704866
# Semakau Island                        12.942591              39.210411
# Sembawang                              9.100547              33.078860
# Sentosa Island                         6.260740              28.992441
# Serangoon                              8.268342              32.607178
# Serangoon North                        8.268342              32.607178
# Simei                                  8.268342              32.607178
# Somerset (Road)                        8.268342              32.607178
# Tai Seng                               8.168725              32.105948
# Tanjong Katong                         8.268342              32.607178
# Tanjong Pagar                          8.268342              32.607178
# Tengah                                 9.073876              31.678757
# Toa Payoh                              8.268342              32.607178
# Tuas                                   8.268342              32.607178
# Tuas South                             6.853781              29.479312
# Tuas West                              8.268342              32.607178
# Ulu Pandan                             8.268342              32.607178
# Upper Peirce Reservoir                 8.268342              32.607178
# Upper Thomson                          8.268342              32.607178
# Whampoa                                8.268342              32.607178
# Yishun                                 8.268342              32.607178
#
# [63 rows x 12 columns]

# %% [markdown]
# We created a lookup table showing the regions that each town belongs to, and how it maps to each weather station.
# As some towns/regions were represented in one dataset but not the other, we only take the intersection.
# For some towns e.g. Choa Chu Kang, there can be a one-to-many relationship to the weather station. We need to be mindful of this and take the mean values for such towns during data cleaning and merging the dataframes.
#
# An easy way would be to drop such towns. However, the more comprehensive way would be to for these 'many-to-one' weather station to town matches, we do some work to take the aggregate mean of the multiple weather stations mapped to the 1 town, before merging both dataframes on the town and the epiweek. This way, there is greater data retention.

# %%
lookuptable = pd.read_excel(filepath + 'Lookup_weather_stations.xlsx')

# %%
lookuptable
# Out:
#              Town      Region          Weather Station
# 0      ang mo kio     Central               Ang Mo Kio
# 1        boon lay        West          Boon Lay (West)
# 2        boon lay        West          Boon Lay (East)
# 3   bukit panjang        West            Bukit Panjang
# 4     bukit timah       South              Bukit Timah
# 5          changi        East                   Changi
# 6   choa chu kang        West  Choa Chu Kang (Central)
# 7   choa chu kang        West    Choa Chu Kang (South)
# 8   choa chu kang        West     Choa Chu Kang (West)
# 9        clementi        West                 Clementi
# 10    jurong east        West            Jurong (East)
# 11  jurong island        West            Jurong Island
# 12    jurong west        West            Jurong (West)
# 13   lim chu kang        West             Lim Chu Kang
# 14         mandai       North                   Mandai
# 15  marine parade        East            Marine Parade
# 16      pasir ris        East      Pasir Ris (Central)
# 17      pasir ris        East         Pasir Ris (West)
# 18     paya lebar        East               Paya Lebar
# 19        punggol  North East                  Punggol
# 20     queenstown       South               Queenstown
# 21        seletar  North East                  Seletar
# 22      sembawang       North                Sembawang
# 23        sentosa       South           Sentosa Island
# 24      serangoon  North East                Serangoon
# 25      serangoon  North East          Serangoon North
# 26         tengah        West                   Tengah
# 27      toa payoh     Central                Toa Payoh
# 28           tuas        West                     Tuas
# 29           tuas        West               Tuas South
# 30           tuas        West                Tuas West
# 31         yishun       North                   Yishun

# %%
list_regions_sub = set(list(lookuptable['Town']))
list_weatherstations_sub = list(lookuptable['Weather Station'])

# %% [markdown]
# Do some merging by location and dates to achieve the final dataframe for modelling

# %%
df_weather['Station Indicator'] = np.where(df_weather['Station'].isin(list_weatherstations_sub), 1, np.nan)
df_weather = df_weather[df_weather['Station Indicator'] == 1] #Filter for those in list
df_weather.head()
# Out:
#    Station  Year  Month  Day  total_rainfall  rainfall_30min  rainfall_60min  \
# 0  Punggol  2012      1    1             9.8        2.599234        3.389148
# 1  Punggol  2012      1    2             0.0        2.599234        3.389148
# 2  Punggol  2012      1    3             0.0        2.599234        3.389148
# 3  Punggol  2012      1    4             0.0        2.599234        3.389148
# 4  Punggol  2012      1    5             0.0        2.599234        3.389148
#
#    rainfall_120min  temperature_mean  temperature_max  temperature_min  \
# 0         4.111853         27.953434        31.714301        25.284095
# 1         4.111853         27.953434        31.714301        25.284095
# 2         4.111853         27.953434        31.714301        25.284095
# 3         4.111853         27.953434        31.714301        25.284095
# 4         4.111853         27.953434        31.714301        25.284095
#
#    windspeed_mean  windspeed_max      Date   Epiweek  Station Indicator
# 0        8.436315       32.78382  1/1/2012  2012-W01                1.0
# 1        8.436315       32.78382  2/1/2012  2012-W01                1.0
# 2        8.436315       32.78382  3/1/2012  2012-W01                1.0
# 3        8.436315       32.78382  4/1/2012  2012-W01                1.0
# 4        8.436315       32.78382  5/1/2012  2012-W01                1.0

# %%
df_weather_combined = df_weather.merge(lookuptable, left_on = 'Station', right_on = 'Weather Station')
df_weather_combined.drop(columns = ['Weather Station', 'Station Indicator'], inplace= True)

# %%
df_weather_combined.head()
# Out:
#    Station  Year  Month  Day  total_rainfall  rainfall_30min  rainfall_60min  \
# 0  Punggol  2012      1    1             9.8        2.599234        3.389148
# 1  Punggol  2012      1    2             0.0        2.599234        3.389148
# 2  Punggol  2012      1    3             0.0        2.599234        3.389148
# 3  Punggol  2012      1    4             0.0        2.599234        3.389148
# 4  Punggol  2012      1    5             0.0        2.599234        3.389148
#
#    rainfall_120min  temperature_mean  temperature_max  temperature_min  \
# 0         4.111853         27.953434        31.714301        25.284095
# 1         4.111853         27.953434        31.714301        25.284095
# 2         4.111853         27.953434        31.714301        25.284095
# 3         4.111853         27.953434        31.714301        25.284095
# 4         4.111853         27.953434        31.714301        25.284095
#
#    windspeed_mean  windspeed_max      Date   Epiweek     Town      Region
# 0        8.436315       32.78382  1/1/2012  2012-W01  punggol  North East
# 1        8.436315       32.78382  2/1/2012  2012-W01  punggol  North East
# 2        8.436315       32.78382  3/1/2012  2012-W01  punggol  North East
# 3        8.436315       32.78382  4/1/2012  2012-W01  punggol  North East
# 4        8.436315       32.78382  5/1/2012  2012-W01  punggol  North East

# %%
df_weather_combined.shape #This will decrease by at least (divide by 7) = ~15K rows
# Out:
# (115830, 17)

# %%
list_manyto1 = ['boon lay', 'choa chu kang', 'pasir ris', 'serangoon', 'tuas']

# %% [markdown]
# Intuition would be to create new columns using np.where to apply the mean value of all those from the same town, epiweek. Then, drop the unnecessary columns of Station, Year, Month, Day (Keep the Date column for merging with gtrends later on). This applies to the whole dataset as there are 7 days in a week, even for those that are not in the many-to-one list.
#
#
# Then, remove the duplicate rows that have the same Epiweek and Town, keeping just the first column. Remember to check the shape of the dataframe at all times.

# %%
columnlist
# Out:
# ['total_rainfall',
#  'rainfall_30min',
#  'rainfall_60min',
#  'rainfall_120min',
#  'temperature_mean',
#  'temperature_max',
#  'temperature_min',
#  'windspeed_mean',
#  'windspeed_max']

# %%
df_weather_combined['total_rainfall'] = df_weather_combined.groupby(['Epiweek', 'Town'])['total_rainfall'].transform(lambda x: x.sum())

# %%
df_weather_combined['rainfall_30min'] = df_weather_combined.groupby(['Epiweek', 'Town'])['rainfall_30min'].transform(lambda x: x.max())
df_weather_combined['rainfall_60min'] = df_weather_combined.groupby(['Epiweek', 'Town'])['rainfall_60min'].transform(lambda x: x.max())
df_weather_combined['rainfall_120min'] = df_weather_combined.groupby(['Epiweek', 'Town'])['rainfall_120min'].transform(lambda x: x.max())

# %%
df_weather_combined['temperature_mean'] = df_weather_combined.groupby(['Epiweek', 'Town'])['temperature_mean'].transform(lambda x: x.mean())
df_weather_combined['temperature_max'] = df_weather_combined.groupby(['Epiweek', 'Town'])['temperature_max'].transform(lambda x: x.max())
df_weather_combined['temperature_min'] = df_weather_combined.groupby(['Epiweek', 'Town'])['temperature_min'].transform(lambda x: x.min())

df_weather_combined['windspeed_mean'] = df_weather_combined.groupby(['Epiweek', 'Town'])['windspeed_mean'].transform(lambda x: x.mean())
df_weather_combined['windspeed_max'] = df_weather_combined.groupby(['Epiweek', 'Town'])['windspeed_max'].transform(lambda x: x.max())

# %%
df_weather_combined.head()
# Out:
#    Station  Year  Month  Day  total_rainfall  rainfall_30min  rainfall_60min  \
# 0  Punggol  2012      1    1            13.8        2.599234        3.389148
# 1  Punggol  2012      1    2            13.8        2.599234        3.389148
# 2  Punggol  2012      1    3            13.8        2.599234        3.389148
# 3  Punggol  2012      1    4            13.8        2.599234        3.389148
# 4  Punggol  2012      1    5            13.8        2.599234        3.389148
#
#    rainfall_120min  temperature_mean  temperature_max  temperature_min  \
# 0         4.111853         27.953434        31.714301        25.284095
# 1         4.111853         27.953434        31.714301        25.284095
# 2         4.111853         27.953434        31.714301        25.284095
# 3         4.111853         27.953434        31.714301        25.284095
# 4         4.111853         27.953434        31.714301        25.284095
#
#    windspeed_mean  windspeed_max      Date   Epiweek     Town      Region
# 0        8.436315       32.78382  1/1/2012  2012-W01  punggol  North East
# 1        8.436315       32.78382  2/1/2012  2012-W01  punggol  North East
# 2        8.436315       32.78382  3/1/2012  2012-W01  punggol  North East
# 3        8.436315       32.78382  4/1/2012  2012-W01  punggol  North East
# 4        8.436315       32.78382  5/1/2012  2012-W01  punggol  North East

# %%
df_weather_combined.shape
# Out:
# (115830, 17)

# %%
df_weather_combined.groupby(['Epiweek', 'Town']).count()
# Out:
#                         Station  Year  Month  Day  total_rainfall  \
# Epiweek  Town
# 2012-W01 ang mo kio           7     7      7    7               7
#          boon lay            14    14     14   14              14
#          bukit panjang        7     7      7    7               7
#          bukit timah          7     7      7    7               7
#          changi               7     7      7    7               7
#          choa chu kang       21    21     21   21              21
#          clementi             7     7      7    7               7
#          jurong east          7     7      7    7               7
#          jurong island        7     7      7    7               7
#          jurong west          7     7      7    7               7
#          lim chu kang         7     7      7    7               7
#          marine parade        7     7      7    7               7
#          pasir ris           14    14     14   14              14
#          paya lebar           7     7      7    7               7
#          punggol              7     7      7    7               7
#          queenstown           7     7      7    7               7
#          seletar              7     7      7    7               7
#          sembawang            7     7      7    7               7
#          sentosa              7     7      7    7               7
#          serangoon           14    14     14   14              14
#          tengah               7     7      7    7               7
#          toa payoh            7     7      7    7               7
#          tuas                21    21     21   21              21
#          yishun               7     7      7    7               7
# 2012-W02 ang mo kio           7     7      7    7               7
#          boon lay            14    14     14   14              14
#          bukit panjang        7     7      7    7               7
#          bukit timah          7     7      7    7               7
#          changi               7     7      7    7               7
#          choa chu kang       21    21     21   21              21
# ...                         ...   ...    ...  ...             ...
# 2022-W47 queenstown           7     7      7    7               7
#          seletar              7     7      7    7               7
#          sembawang            7     7      7    7               7
#          sentosa              7     7      7    7               7
#          serangoon            7     7      7    7               7
#          tengah               7     7      7    7               7
#          toa payoh            7     7      7    7               7
#          tuas                21    21     21   21              21
# 2022-W48 ang mo kio           4     4      4    4               4
#          bukit panjang        4     4      4    4               4
#          bukit timah          4     4      4    4               4
#          changi               4     4      4    4               4
#          choa chu kang        8     8      8    8               8
#          clementi             4     4      4    4               4
#          jurong island        4     4      4    4               4
#          jurong west          4     4      4    4               4
#          lim chu kang         4     4      4    4               4
#          mandai               4     4      4    4               4
#          marine parade        4     4      4    4               4
#          pasir ris            8     8      8    8               8
#          paya lebar           4     4      4    4               4
#          punggol              4     4      4    4               4
#          queenstown           4     4      4    4               4
#          seletar              4     4      4    4               4
#          sembawang            4     4      4    4               4
#          sentosa              4     4      4    4               4
#          serangoon            4     4      4    4               4
#          tengah               4     4      4    4               4
#          toa payoh            4     4      4    4               4
#          tuas                12    12     12   12              12
#
#                         rainfall_30min  rainfall_60min  rainfall_120min  \
# Epiweek  Town
# 2012-W01 ang mo kio                  7               7                7
#          boon lay                   14              14               14
#          bukit panjang               7               7                7
#          bukit timah                 7               7                7
#          changi                      7               7                7
#          choa chu kang              21              21               21
#          clementi                    7               7                7
#          jurong east                 7               7                7
#          jurong island               7               7                7
#          jurong west                 7               7                7
#          lim chu kang                7               7                7
#          marine parade               7               7                7
#          pasir ris                  14              14               14
#          paya lebar                  7               7                7
#          punggol                     7               7                7
#          queenstown                  7               7                7
#          seletar                     7               7                7
#          sembawang                   7               7                7
#          sentosa                     7               7                7
#          serangoon                  14              14               14
#          tengah                      7               7                7
#          toa payoh                   7               7                7
#          tuas                       21              21               21
#          yishun                      7               7                7
# 2012-W02 ang mo kio                  7               7                7
#          boon lay                   14              14               14
#          bukit panjang               7               7                7
#          bukit timah                 7               7                7
#          changi                      7               7                7
#          choa chu kang              21              21               21
# ...                                ...             ...              ...
# 2022-W47 queenstown                  7               7                7
#          seletar                     7               7                7
#          sembawang                   7               7                7
#          sentosa                     7               7                7
#          serangoon                   7               7                7
#          tengah                      7               7                7
#          toa payoh                   7               7                7
#          tuas                       21              21               21
# 2022-W48 ang mo kio                  4               4                4
#          bukit panjang               4               4                4
#          bukit timah                 4               4                4
#          changi                      4               4                4
#          choa chu kang               8               8                8
#          clementi                    4               4                4
#          jurong island               4               4                4
#          jurong west                 4               4                4
#          lim chu kang                4               4                4
#          mandai                      4               4                4
#          marine parade               4               4                4
#          pasir ris                   8               8                8
#          paya lebar                  4               4                4
#          punggol                     4               4                4
#          queenstown                  4               4                4
#          seletar                     4               4                4
#          sembawang                   4               4                4
#          sentosa                     4               4                4
#          serangoon                   4               4                4
#          tengah                      4               4                4
#          toa payoh                   4               4                4
#          tuas                       12              12               12
#
#                         temperature_mean  temperature_max  temperature_min  \
# Epiweek  Town
# 2012-W01 ang mo kio                    7                7                7
#          boon lay                     14               14               14
#          bukit panjang                 7                7                7
#          bukit timah                   7                7                7
#          changi                        7                7                7
#          choa chu kang                21               21               21
#          clementi                      7                7                7
#          jurong east                   7                7                7
#          jurong island                 7                7                7
#          jurong west                   7                7                7
#          lim chu kang                  7                7                7
#          marine parade                 7                7                7
#          pasir ris                    14               14               14
#          paya lebar                    7                7                7
#          punggol                       7                7                7
#          queenstown                    7                7                7
#          seletar                       7                7                7
#          sembawang                     7                7                7
#          sentosa                       7                7                7
#          serangoon                    14               14               14
#          tengah                        7                7                7
#          toa payoh                     7                7                7
#          tuas                         21               21               21
#          yishun                        7                7                7
# 2012-W02 ang mo kio                    7                7                7
#          boon lay                     14               14               14
#          bukit panjang                 7                7                7
#          bukit timah                   7                7                7
#          changi                        7                7                7
#          choa chu kang                21               21               21
# ...                                  ...              ...              ...
# 2022-W47 queenstown                    7                7                7
#          seletar                       7                7                7
#          sembawang                     7                7                7
#          sentosa                       7                7                7
#          serangoon                     7                7                7
#          tengah                        7                7                7
#          toa payoh                     7                7                7
#          tuas                         21               21               21
# 2022-W48 ang mo kio                    4                4                4
#          bukit panjang                 4                4                4
#          bukit timah                   4                4                4
#          changi                        4                4                4
#          choa chu kang                 8                8                8
#          clementi                      4                4                4
#          jurong island                 4                4                4
#          jurong west                   4                4                4
#          lim chu kang                  4                4                4
#          mandai                        4                4                4
#          marine parade                 4                4                4
#          pasir ris                     8                8                8
#          paya lebar                    4                4                4
#          punggol                       4                4                4
#          queenstown                    4                4                4
#          seletar                       4                4                4
#          sembawang                     4                4                4
#          sentosa                       4                4                4
#          serangoon                     4                4                4
#          tengah                        4                4                4
#          toa payoh                     4                4                4
#          tuas                         12               12               12
#
#                         windspeed_mean  windspeed_max  Date  Region
# Epiweek  Town
# 2012-W01 ang mo kio                  7              7     7       7
#          boon lay                   14             14    14      14
#          bukit panjang               7              7     7       7
#          bukit timah                 7              7     7       7
#          changi                      7              7     7       7
#          choa chu kang              21             21    21      21
#          clementi                    7              7     7       7
#          jurong east                 7              7     7       7
#          jurong island               7              7     7       7
#          jurong west                 7              7     7       7
#          lim chu kang                7              7     7       7
#          marine parade               7              7     7       7
#          pasir ris                  14             14    14      14
#          paya lebar                  7              7     7       7
#          punggol                     7              7     7       7
#          queenstown                  7              7     7       7
#          seletar                     7              7     7       7
#          sembawang                   7              7     7       7
#          sentosa                     7              7     7       7
#          serangoon                  14             14    14      14
#          tengah                      7              7     7       7
#          toa payoh                   7              7     7       7
#          tuas                       21             21    21      21
#          yishun                      7              7     7       7
# 2012-W02 ang mo kio                  7              7     7       7
#          boon lay                   14             14    14      14
#          bukit panjang               7              7     7       7
#          bukit timah                 7              7     7       7
#          changi                      7              7     7       7
#          choa chu kang              21             21    21      21
# ...                                ...            ...   ...     ...
# 2022-W47 queenstown                  7              7     7       7
#          seletar                     7              7     7       7
#          sembawang                   7              7     7       7
#          sentosa                     7              7     7       7
#          serangoon                   7              7     7       7
#          tengah                      7              7     7       7
#          toa payoh                   7              7     7       7
#          tuas                       21             21    21      21
# 2022-W48 ang mo kio                  4              4     4       4
#          bukit panjang               4              4     4       4
#          bukit timah                 4              4     4       4
#          changi                      4              4     4       4
#          choa chu kang               8              8     8       8
#          clementi                    4              4     4       4
#          jurong island               4              4     4       4
#          jurong west                 4              4     4       4
#          lim chu kang                4              4     4       4
#          mandai                      4              4     4       4
#          marine parade               4              4     4       4
#          pasir ris                   8              8     8       8
#          paya lebar                  4              4     4       4
#          punggol                     4              4     4       4
#          queenstown                  4              4     4       4
#          seletar                     4              4     4       4
#          sembawang                   4              4     4       4
#          sentosa                     4              4     4       4
#          serangoon                   4              4     4       4
#          tengah                      4              4     4       4
#          toa payoh                   4              4     4       4
#          tuas                       12             12    12      12
#
# [13360 rows x 15 columns]

# %%
df_weather_combined_unique = df_weather_combined.drop_duplicates(subset=['Epiweek', 'Town'], keep='first')

# %%
df_weather_combined_unique.shape
# Out:
# (13360, 17)

# %%
df_weather_combined_unique.head()
# Out:
#     Station  Year  Month  Day  total_rainfall  rainfall_30min  rainfall_60min  \
# 0   Punggol  2012      1    1            13.8        2.599234        3.389148
# 7   Punggol  2012      1    8            29.6        2.599234        3.389148
# 14  Punggol  2012      1   15            66.4        2.599234        3.389148
# 21  Punggol  2012      1   22            16.0        2.599234        3.389148
# 28  Punggol  2012      1   29            53.2        2.599234        3.389148
#
#     rainfall_120min  temperature_mean  temperature_max  temperature_min  \
# 0          4.111853         27.953434        31.714301        25.284095
# 7          4.111853         27.953434        31.714301        25.284095
# 14         4.111853         27.953434        31.714301        25.284095
# 21         4.111853         27.953434        31.714301        25.284095
# 28         4.111853         27.953434        31.714301        25.284095
#
#     windspeed_mean  windspeed_max       Date   Epiweek     Town      Region
# 0         8.436315       32.78382   1/1/2012  2012-W01  punggol  North East
# 7         8.436315       32.78382   8/1/2012  2012-W02  punggol  North East
# 14        8.436315       32.78382  15/1/2012  2012-W03  punggol  North East
# 21        8.436315       32.78382  22/1/2012  2012-W04  punggol  North East
# 28        8.436315       32.78382  29/1/2012  2012-W05  punggol  North East

# %%
#Shortcut to drop those many-to-one
#df_weather_combined2 = df_weather_combined
#df_weather_combined2['Indicator'] = np.where(df_weather_combined2['Town'].isin(list_manyto1), np.nan, 1)
#df_weather_combined2 = df_weather_combined2[df_weather_combined2['Indicator'] == 1] #Filter for those in list
#df_weather_combined2.drop(columns = ['Indicator'], inplace = True)

# %%
grouped = df_weather_combined_unique.groupby(['Town', 'Epiweek'])
grouped.max()
# Out:
#                         Station  Year  Month  Day  total_rainfall  \
# Town       Epiweek
# ang mo kio 2012-W01  Ang Mo Kio  2012      1    1        3.800000
#            2012-W02  Ang Mo Kio  2012      1    8       32.400000
#            2012-W03  Ang Mo Kio  2012      1   15      101.400000
#            2012-W04  Ang Mo Kio  2012      1   22       30.400000
#            2012-W05  Ang Mo Kio  2012      1   29       85.600000
#            2012-W06  Ang Mo Kio  2012      2    5        0.000000
#            2012-W07  Ang Mo Kio  2012      2   12       25.800000
#            2012-W08  Ang Mo Kio  2012      2   19       21.200000
#            2012-W09  Ang Mo Kio  2012      3    1       28.600000
#            2012-W10  Ang Mo Kio  2012      3    4       24.400000
#            2012-W11  Ang Mo Kio  2012      3   11       69.600000
#            2012-W12  Ang Mo Kio  2012      3   18       38.400000
#            2012-W13  Ang Mo Kio  2012      3   25      104.400000
#            2012-W14  Ang Mo Kio  2012      4    1       87.000000
#            2012-W15  Ang Mo Kio  2012      4    8      117.800000
#            2012-W16  Ang Mo Kio  2012      4   15       37.600000
#            2012-W17  Ang Mo Kio  2012      4   22        2.000000
#            2012-W18  Ang Mo Kio  2012      5    1       87.600000
#            2012-W19  Ang Mo Kio  2012      5    6       81.200000
#            2012-W20  Ang Mo Kio  2012      5   13       21.800000
#            2012-W21  Ang Mo Kio  2012      5   20       44.200000
#            2012-W22  Ang Mo Kio  2012      6    1       25.000000
#            2012-W23  Ang Mo Kio  2012      6    3       50.000000
#            2012-W24  Ang Mo Kio  2012      6   10        0.000000
#            2012-W25  Ang Mo Kio  2012      6   17       16.000000
#            2012-W26  Ang Mo Kio  2012      6   24       78.800000
#            2012-W27  Ang Mo Kio  2012      7    1      115.600000
#            2012-W28  Ang Mo Kio  2012      7    8       27.400000
#            2012-W29  Ang Mo Kio  2012      7   15       30.600000
#            2012-W30  Ang Mo Kio  2012      7   22        0.400000
# ...                         ...   ...    ...  ...             ...
# yishun     2020-W41      Yishun  2020     10    4       15.000000
#            2020-W42      Yishun  2020     10   11       25.800000
#            2020-W43      Yishun  2020     10   18       22.800000
#            2020-W44      Yishun  2020     10   25       47.600000
#            2020-W45      Yishun  2020     11    1       90.200000
#            2020-W46      Yishun  2020     11    8       31.400000
#            2020-W47      Yishun  2020     11   15      108.600000
#            2020-W48      Yishun  2020     11   22       41.400000
#            2020-W49      Yishun  2020     12    1       38.600000
#            2020-W50      Yishun  2020     12    6       73.400000
#            2020-W51      Yishun  2020     12   13       52.400000
#            2020-W52      Yishun  2020     12   20       57.200000
#            2020-W53      Yishun  2020     12   27      256.200000
#            2021-W01      Yishun  2021      1    3       44.800000
#            2021-W02      Yishun  2021      1   10      156.737931
#            2021-W03      Yishun  2021      1   17       72.600000
#            2021-W04      Yishun  2021      1   24        2.800000
#            2021-W05      Yishun  2021      2    1        0.000000
#            2021-W06      Yishun  2021      2    7       27.000000
#            2021-W07      Yishun  2021      2   14        0.400000
#            2021-W08      Yishun  2021      2   21        6.400000
#            2021-W09      Yishun  2021      3    1        0.000000
#            2021-W10      Yishun  2021      3    7       92.800000
#            2021-W11      Yishun  2021      3   14       56.533333
#            2021-W12      Yishun  2021      3   21       52.266667
#            2021-W13      Yishun  2021      3   28       49.296871
#            2021-W14      Yishun  2021      4    4       45.337143
#            2021-W15      Yishun  2021      4   11       45.337143
#            2021-W16      Yishun  2021      4   18       45.337143
#            2021-W17      Yishun  2021      4   25       38.860408
#
#                      rainfall_30min  rainfall_60min  rainfall_120min  \
# Town       Epiweek
# ang mo kio 2012-W01        3.044803        4.006810         4.733692
#            2012-W02        3.044803        4.006810         4.733692
#            2012-W03        3.044803        4.006810         4.733692
#            2012-W04        3.044803        4.006810         4.733692
#            2012-W05        3.044803        4.006810         4.733692
#            2012-W06        2.053543        2.437008         2.848031
#            2012-W07        2.053543        2.437008         2.848031
#            2012-W08        2.053543        2.437008         2.848031
#            2012-W09        3.959034        4.773226         5.323090
#            2012-W10        3.959034        4.773226         5.323090
#            2012-W11        3.959034        4.773226         5.323090
#            2012-W12        3.959034        4.773226         5.323090
#            2012-W13        3.959034        4.773226         5.323090
#            2012-W14        6.141481        7.494815         8.187407
#            2012-W15        6.141481        7.494815         8.187407
#            2012-W16        6.141481        7.494815         8.187407
#            2012-W17        6.141481        7.494815         8.187407
#            2012-W18        6.141481        7.494815         8.187407
#            2012-W19        4.218408        5.170072         5.854992
#            2012-W20        4.218408        5.170072         5.854992
#            2012-W21        4.218408        5.170072         5.854992
#            2012-W22        4.218408        5.170072         5.854992
#            2012-W23        3.740979        4.576394         5.233173
#            2012-W24        3.740979        4.576394         5.233173
#            2012-W25        3.740979        4.576394         5.233173
#            2012-W26        3.740979        4.576394         5.233173
#            2012-W27        3.474389        4.231297         4.601376
#            2012-W28        3.474389        4.231297         4.601376
#            2012-W29        3.474389        4.231297         4.601376
#            2012-W30        3.474389        4.231297         4.601376
# ...                             ...             ...              ...
# yishun     2020-W41        2.600000        3.400000         5.000000
#            2020-W42       14.000000       14.000000        14.000000
#            2020-W43        9.400000        9.400000         9.400000
#            2020-W44       26.200000       26.600000        26.800000
#            2020-W45       29.400000       34.400000        37.000000
#            2020-W46       10.400000       11.200000        12.000000
#            2020-W47       26.800000       35.400000        44.200000
#            2020-W48       21.800000       26.400000        30.800000
#            2020-W49       27.400000       28.200000        29.800000
#            2020-W50       18.800000       19.400000        23.200000
#            2020-W51       10.600000       10.800000        10.800000
#            2020-W52       30.800000       39.200000        40.600000
#            2020-W53       15.800000       28.400000        49.800000
#            2021-W01       10.000000       14.200000        15.000000
#            2021-W02       11.800000       16.000000        25.400000
#            2021-W03       27.600000       33.600000        37.600000
#            2021-W04        1.000000        1.200000         1.400000
#            2021-W05        0.000000        0.000000         0.000000
#            2021-W06       19.000000       19.000000        20.400000
#            2021-W07        0.400000        0.400000         0.400000
#            2021-W08        4.200000        4.800000         6.200000
#            2021-W09        0.000000        0.000000         0.000000
#            2021-W10       27.200000       33.000000        33.600000
#            2021-W11        9.000000       11.200000        19.000000
#            2021-W12        4.560000        5.520000         6.466667
#            2021-W13        4.560000        5.520000         6.466667
#            2021-W14        4.376349        5.412063         5.955238
#            2021-W15        4.376349        5.412063         5.955238
#            2021-W16        4.376349        5.412063         5.955238
#            2021-W17        4.376349        5.412063         5.955238
#
#                      temperature_mean  temperature_max  temperature_min  \
# Town       Epiweek
# ang mo kio 2012-W01         26.928571        31.600000        24.100000
#            2012-W02         25.928571        32.500000        23.500000
#            2012-W03         27.142857        34.600000        22.000000
#            2012-W04         26.300000        32.800000        23.400000
#            2012-W05         26.200000        32.500000        21.800000
#            2012-W06         27.228571        32.600000        23.700000
#            2012-W07         26.685714        33.300000        23.700000
#            2012-W08         27.200000        33.700000        22.500000
#            2012-W09         27.057143        33.500000        22.700000
#            2012-W10         27.157143        33.200000        22.600000
#            2012-W11         26.257143        32.800000        22.800000
#            2012-W12         27.557143        34.400000        23.500000
#            2012-W13         26.857143        33.400000        22.200000
#            2012-W14         27.471429        33.300000        22.100000
#            2012-W15         27.071429        33.400000        22.900000
#            2012-W16         27.642857        34.300000        23.900000
#            2012-W17         28.571429        34.800000        23.800000
#            2012-W18         28.085714        33.200000        21.900000
#            2012-W19         27.700000        34.300000        22.300000
#            2012-W20         28.742857        33.800000        23.000000
#            2012-W21         28.514286        33.100000        24.200000
#            2012-W22         28.128571        33.300000        22.200000
#            2012-W23         28.671429        33.200000        22.800000
#            2012-W24         29.528571        33.800000        26.000000
#            2012-W25         29.000000        33.600000        25.400000
#            2012-W26         28.600000        33.300000        23.400000
#            2012-W27         27.185714        31.500000        23.000000
#            2012-W28         27.514286        31.800000        23.200000
#            2012-W29         27.128571        32.400000        24.200000
#            2012-W30         29.028571        32.900000        24.700000
# ...                               ...              ...              ...
# yishun     2020-W41         27.953434        31.714301        25.284095
#            2020-W42         27.953434        31.714301        25.284095
#            2020-W43         27.953434        31.714301        25.284095
#            2020-W44         27.953434        31.714301        25.284095
#            2020-W45         27.953434        31.714301        25.284095
#            2020-W46         27.953434        31.714301        25.284095
#            2020-W47         27.953434        31.714301        25.284095
#            2020-W48         27.953434        31.714301        25.284095
#            2020-W49         27.953434        31.714301        25.284095
#            2020-W50         27.953434        31.714301        25.284095
#            2020-W51         27.953434        31.714301        25.284095
#            2020-W52         27.953434        31.714301        25.284095
#            2020-W53         27.953434        31.714301        25.284095
#            2021-W01         27.953434        31.714301        25.284095
#            2021-W02         27.953434        31.714301        25.284095
#            2021-W03         27.953434        31.714301        25.284095
#            2021-W04         27.953434        31.714301        25.284095
#            2021-W05         27.953434        31.714301        25.284095
#            2021-W06         27.953434        31.714301        25.284095
#            2021-W07         27.953434        31.714301        25.284095
#            2021-W08         27.953434        31.714301        25.284095
#            2021-W09         27.953434        31.714301        25.284095
#            2021-W10         27.953434        31.714301        25.284095
#            2021-W11         27.953434        31.714301        25.284095
#            2021-W12         27.953434        31.714301        25.284095
#            2021-W13         27.953434        31.714301        25.284095
#            2021-W14         27.953434        31.714301        25.284095
#            2021-W15         27.953434        31.714301        25.284095
#            2021-W16         27.953434        31.714301        25.284095
#            2021-W17         27.953434        31.714301        25.284095
#
#                      windspeed_mean  windspeed_max        Date   Region
# Town       Epiweek
# ang mo kio 2012-W01        8.228571       40.30000    1/1/2012  Central
#            2012-W02        6.814286       36.00000    8/1/2012  Central
#            2012-W03        4.971429       36.70000   15/1/2012  Central
#            2012-W04        6.628571       35.30000   22/1/2012  Central
#            2012-W05        6.785714       37.40000   29/1/2012  Central
#            2012-W06        7.714286       35.60000    5/2/2012  Central
#            2012-W07        6.057143       40.30000   12/2/2012  Central
#            2012-W08        5.928571       33.50000   19/2/2012  Central
#            2012-W09        5.371429       41.00000    1/3/2012  Central
#            2012-W10        4.757143       44.30000    4/3/2012  Central
#            2012-W11        5.742857       38.50000   11/3/2012  Central
#            2012-W12        4.414286       33.50000   18/3/2012  Central
#            2012-W13        4.971429       62.60000   25/3/2012  Central
#            2012-W14        4.942857       47.90000    1/4/2012  Central
#            2012-W15        4.371429       37.80000    8/4/2012  Central
#            2012-W16        4.700000       32.40000   15/4/2012  Central
#            2012-W17        5.385714       34.90000   22/4/2012  Central
#            2012-W18        4.757143       77.40000    1/5/2012  Central
#            2012-W19        4.485714       47.90000    6/5/2012  Central
#            2012-W20        5.557143       64.80000   13/5/2012  Central
#            2012-W21        5.700000       32.40000   20/5/2012  Central
#            2012-W22        4.900000       49.70000    1/6/2012  Central
#            2012-W23        5.342857       36.40000    3/6/2012  Central
#            2012-W24        6.928571       31.30000   10/6/2012  Central
#            2012-W25        6.771429       37.80000   17/6/2012  Central
#            2012-W26        6.014286       42.80000   24/6/2012  Central
#            2012-W27        5.357143       38.90000    1/7/2012  Central
#            2012-W28        5.871429       34.20000    8/7/2012  Central
#            2012-W29        4.957143       34.60000   15/7/2012  Central
#            2012-W30        7.785714       44.30000   22/7/2012  Central
# ...                             ...            ...         ...      ...
# yishun     2020-W41        8.436315       32.78382   4/10/2020    North
#            2020-W42        8.436315       32.78382  11/10/2020    North
#            2020-W43        8.436315       32.78382  18/10/2020    North
#            2020-W44        8.436315       32.78382  25/10/2020    North
#            2020-W45        8.436315       32.78382   1/11/2020    North
#            2020-W46        8.436315       32.78382   8/11/2020    North
#            2020-W47        8.436315       32.78382  15/11/2020    North
#            2020-W48        8.436315       32.78382  22/11/2020    North
#            2020-W49        8.436315       32.78382   1/12/2020    North
#            2020-W50        8.436315       32.78382   6/12/2020    North
#            2020-W51        8.436315       32.78382  13/12/2020    North
#            2020-W52        8.436315       32.78382  20/12/2020    North
#            2020-W53        8.436315       32.78382  27/12/2020    North
#            2021-W01        8.436315       32.78382    3/1/2021    North
#            2021-W02        8.436315       32.78382   10/1/2021    North
#            2021-W03        8.436315       32.78382   17/1/2021    North
#            2021-W04        8.436315       32.78382   24/1/2021    North
#            2021-W05        8.436315       32.78382    1/2/2021    North
#            2021-W06        8.436315       32.78382    7/2/2021    North
#            2021-W07        8.436315       32.78382   14/2/2021    North
#            2021-W08        8.436315       32.78382   21/2/2021    North
#            2021-W09        8.436315       32.78382    1/3/2021    North
#            2021-W10        8.436315       32.78382    7/3/2021    North
#            2021-W11        8.436315       32.78382   14/3/2021    North
#            2021-W12        8.436315       32.78382   21/3/2021    North
#            2021-W13        8.436315       32.78382   28/3/2021    North
#            2021-W14        8.436315       32.78382    4/4/2021    North
#            2021-W15        8.436315       32.78382   11/4/2021    North
#            2021-W16        8.436315       32.78382   18/4/2021    North
#            2021-W17        8.436315       32.78382   25/4/2021    North
#
# [13360 rows x 15 columns]

# %% [markdown]
# Inner Join with `df_total_dengue_cases`

# %%
df_total_dengue_cases.head()
# Out:
#   epi_week_year      start        end     actual        town  dengue_cases
# 0      2013-W21  19/5/2013  25/5/2013  23/5/2013  ang mo kio           0.0
# 1      2013-W22  26/5/2013   1/6/2013  27/5/2013  ang mo kio           0.0
# 2      2013-W23   2/6/2013   8/6/2013  11/6/2013  ang mo kio          23.0
# 3      2013-W24   9/6/2013  15/6/2013  11/6/2013  ang mo kio          23.0
# 4      2013-W25  16/6/2013  22/6/2013  17/6/2013  ang mo kio          11.0

# %%
df_weather_combined_unique.head()
# Out:
#     Station  Year  Month  Day  total_rainfall  rainfall_30min  rainfall_60min  \
# 0   Punggol  2012      1    1            13.8        2.599234        3.389148
# 7   Punggol  2012      1    8            29.6        2.599234        3.389148
# 14  Punggol  2012      1   15            66.4        2.599234        3.389148
# 21  Punggol  2012      1   22            16.0        2.599234        3.389148
# 28  Punggol  2012      1   29            53.2        2.599234        3.389148
#
#     rainfall_120min  temperature_mean  temperature_max  temperature_min  \
# 0          4.111853         27.953434        31.714301        25.284095
# 7          4.111853         27.953434        31.714301        25.284095
# 14         4.111853         27.953434        31.714301        25.284095
# 21         4.111853         27.953434        31.714301        25.284095
# 28         4.111853         27.953434        31.714301        25.284095
#
#     windspeed_mean  windspeed_max       Date   Epiweek     Town      Region
# 0         8.436315       32.78382   1/1/2012  2012-W01  punggol  North East
# 7         8.436315       32.78382   8/1/2012  2012-W02  punggol  North East
# 14        8.436315       32.78382  15/1/2012  2012-W03  punggol  North East
# 21        8.436315       32.78382  22/1/2012  2012-W04  punggol  North East
# 28        8.436315       32.78382  29/1/2012  2012-W05  punggol  North East

# %%
df = df_total_dengue_cases.merge(df_weather_combined_unique, left_on = ['town', 'epi_week_year'], right_on = ['Town', 'Epiweek'], how = 'inner')

# %%
#check shape before and after merging
print(df_total_dengue_cases.shape)
print(df_weather_combined_unique.shape)
print(df.shape)
# Out:
# (19314, 6)
# (13360, 17)
# (9219, 23)

# %% [markdown]
# No idea why there is massive number of duplicates (109 rows for only the epiweek 2013-W21 for each of the 25 towns, so I shall drop duplicates again. This should drop around 2600 rows.

# %%
df2 = df.drop_duplicates(subset=['Epiweek', 'Town'], keep='first')

# %%
df2.head()
# Out:
#     epi_week_year      start        end     actual        town  dengue_cases  \
# 0        2013-W21  19/5/2013  25/5/2013  23/5/2013  ang mo kio           0.0
# 109      2013-W22  26/5/2013   1/6/2013  27/5/2013  ang mo kio           0.0
# 110      2013-W23   2/6/2013   8/6/2013  11/6/2013  ang mo kio          23.0
# 111      2013-W24   9/6/2013  15/6/2013  11/6/2013  ang mo kio          23.0
# 112      2013-W25  16/6/2013  22/6/2013  17/6/2013  ang mo kio          11.0
#
#         Station  Year  Month  Day   ...     rainfall_120min  temperature_mean  \
# 0    Ang Mo Kio  2013      5   19   ...            5.854992         28.300000
# 109  Ang Mo Kio  2013      5   26   ...            5.854992         27.685714
# 110  Ang Mo Kio  2013      6    2   ...            5.233173         27.985714
# 111  Ang Mo Kio  2013      6    9   ...            5.233173         29.742857
# 112  Ang Mo Kio  2013      6   16   ...            5.233173         30.385714
#
#      temperature_max  temperature_min  windspeed_mean  windspeed_max  \
# 0               34.9             22.7        4.100000           38.9
# 109             34.3             23.0        4.371429           64.8
# 110             35.5             23.2        4.357143           48.2
# 111             34.1             24.2        6.328571           39.2
# 112             34.6             26.8        6.300000           43.9
#
#           Date   Epiweek        Town   Region
# 0    19/5/2013  2013-W21  ang mo kio  Central
# 109  26/5/2013  2013-W22  ang mo kio  Central
# 110   2/6/2013  2013-W23  ang mo kio  Central
# 111   9/6/2013  2013-W24  ang mo kio  Central
# 112  16/6/2013  2013-W25  ang mo kio  Central
#
# [5 rows x 23 columns]

# %%
df2.shape
# Out:
# (9219, 23)

# %%
df2.isna().sum() #Eliminated or imputed all null values
# Out:
# epi_week_year       0
# start               0
# dengue_cases        0
# Station             0
# Year                0
# Month               0
# Day                 0
# total_rainfall      0
# rainfall_30min      0
# rainfall_60min      0
# rainfall_120min     0
# temperature_mean    0
# temperature_max     0
# temperature_min     0
# windspeed_mean      0
# windspeed_max       0
# Date                0
# Epiweek             0
# Town                0
# Region              0
# dtype: int64

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9219 entries, 0 to 11810
# Data columns (total 20 columns):
# epi_week_year       9219 non-null object
# start               9219 non-null object
# dengue_cases        9219 non-null float64
# Station             9219 non-null object
# Year                9219 non-null int64
# Month               9219 non-null int64
# Day                 9219 non-null int64
# total_rainfall      9219 non-null float64
# rainfall_30min      9219 non-null float64
# rainfall_60min      9219 non-null float64
# rainfall_120min     9219 non-null float64
# temperature_mean    9219 non-null float64
# temperature_max     9219 non-null float64
# temperature_min     9219 non-null float64
# windspeed_mean      9219 non-null float64
# windspeed_max       9219 non-null float64
# Date                9219 non-null object
# Epiweek             9219 non-null object
# Town                9219 non-null object
# Region              9219 non-null object
# dtypes: float64(10), int64(3), object(7)
# memory usage: 1.5+ MB

# %%
df2.drop(columns = ['town', 'end', 'actual'],inplace = True)
# Out:
# C:\Users\gohch\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df2.to_excel('Output after Merged.xlsx', index=False)

# %% [markdown]
# #### Import the rescaled Google Trends data
# Google Trends data were scraped for the keywords 'Dengue fever' and 'Wolbachia'. This was done for weekly data and there were no missing values.

# %%
# Load the data from the JSON file
with open('data/rescaled_dengue fever.json', 'r') as f:
    data = json.load(f)

# Initialize an empty list to store the reformatted data
formatted_data = []

# Loop through each year and the data for that year
for year, year_data in data:
    # Convert the year data into a Pandas DataFrame
    dengue_fever = pd.DataFrame.from_dict(year_data, orient='index')
    dengue_fever.index.name = 'date'
    dengue_fever.reset_index(inplace=True)
    dengue_fever['date'] = pd.to_datetime(dengue_fever['date'])
    dengue_fever['year'] = year
    formatted_data.append(dengue_fever)

# Concatenate all of the year data into a single DataFrame
dengue_fever = pd.concat(formatted_data)

# %%
dengue_fever.columns = ['date', 'freq_dengue_gtrends', 'year']

# %%
dengue_fever.head()
# Out:
#         date  freq_dengue_gtrends  year
# 0 2012-01-01            84.658373  2012
# 1 2012-01-08            77.483935  2012
# 2 2012-01-15            28.697754  2012
# 3 2012-01-22            77.483935  2012
# 4 2012-01-29            50.221069  2012

# %% [markdown]
# Google Trends - Wolbachia

# %%
with open('data/rescaled_wolbachia.json', 'r') as f:
    data = json.load(f)

# Initialize an empty list to store the reformatted data
formatted_data = []

# Loop through each year and the data for that year
for year, year_data in data:
    # Convert the year data into a Pandas DataFrame
    wolbachia = pd.DataFrame.from_dict(year_data, orient='index')
    wolbachia.index.name = 'date'
    wolbachia.reset_index(inplace=True)
    wolbachia['date'] = pd.to_datetime(wolbachia['date'])
    wolbachia['year'] = year
    formatted_data.append(wolbachia)

# Concatenate all of the year data into a single DataFrame
wolbachia = pd.concat(formatted_data)

# %%
wolbachia.columns = ['date', 'freq_wolbachia_gtrends', 'year']

# %%
wolbachia.head()
# Out:
#         date  freq_wolbachia_gtrends  year
# 0 2012-01-01                     0.0  2012
# 1 2012-01-08                     0.0  2012
# 2 2012-01-15                     0.0  2012
# 3 2012-01-22                     0.0  2012
# 4 2012-01-29                     0.0  2012

# %%
dengue_fever.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 488 entries, 0 to 54
# Data columns (total 3 columns):
# date                   488 non-null datetime64[ns]
# freq_dengue_gtrends    488 non-null float64
# year                   488 non-null int64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 15.2 KB

# %%
wolbachia.info() #There are no null values for either of the Google trends data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 488 entries, 0 to 54
# Data columns (total 3 columns):
# date                      488 non-null datetime64[ns]
# freq_wolbachia_gtrends    488 non-null float64
# year                      488 non-null int64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 15.2 KB

# %% [markdown]
# Merging both into one dataframe

# %%
freq_gtrends = dengue_fever.merge(wolbachia, on =['date','year'])
freq_gtrends.head()
# Out:
#         date  freq_dengue_gtrends  year  freq_wolbachia_gtrends
# 0 2012-01-01            84.658373  2012                     0.0
# 1 2012-01-08            77.483935  2012                     0.0
# 2 2012-01-15            28.697754  2012                     0.0
# 3 2012-01-22            77.483935  2012                     0.0
# 4 2012-01-29            50.221069  2012                     0.0

# %%
print(freq_gtrends.shape) # No loss or extra columns
# Out:
# (488, 4)

# %%
freq_gtrends.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 488 entries, 0 to 487
# Data columns (total 4 columns):
# date                      488 non-null datetime64[ns]
# freq_dengue_gtrends       488 non-null float64
# year                      488 non-null int64
# freq_wolbachia_gtrends    488 non-null float64
# dtypes: datetime64[ns](1), float64(2), int64(1)
# memory usage: 19.1 KB

# %% [markdown]
# In order to merge with the df2 dataframe, we will need to convert the date to type 'str', or add a column called Epiweek. We shall try to first directly convert to str and replace all '-' with '/' to match the format of df2 'Date' column.

# %%
test=freq_gtrends['date'][1]

# %%
test
# Out:
# Timestamp('2012-01-08 00:00:00')

# %%
#freq_gtrends['date_new'] = freq_gtrends['date'].apply(lambda x: str(x).replace('-','/'))
freq_gtrends['date_new'] = freq_gtrends['date'].apply(lambda x: x.strftime("%#d/%#m/%Y"))

# %%
freq_gtrends['date_new'].tail()
# Out:
# 483     6/12/2020
# 484    13/12/2020
# 485    20/12/2020
# 486    27/12/2020
# 487      3/1/2021
# Name: date_new, dtype: object

# %% [markdown]
# ### Merging Google Trends into the final dataframe

# %%
df2.tail()
# Out:
#       epi_week_year       start  dengue_cases Station  Year  Month  Day  \
# 11806      2020-W41   4/10/2020           0.0  Yishun  2020     10    4
# 11807      2020-W42  11/10/2020           0.0  Yishun  2020     10   11
# 11808      2020-W43  18/10/2020           0.0  Yishun  2020     10   18
# 11809      2020-W44  25/10/2020           0.0  Yishun  2020     10   25
# 11810      2020-W45   1/11/2020           0.0  Yishun  2020     11    1
#
#        total_rainfall  rainfall_30min  rainfall_60min  rainfall_120min  \
# 11806            15.0             2.6             3.4              5.0
# 11807            25.8            14.0            14.0             14.0
# 11808            22.8             9.4             9.4              9.4
# 11809            47.6            26.2            26.6             26.8
# 11810            90.2            29.4            34.4             37.0
#
#        temperature_mean  temperature_max  temperature_min  windspeed_mean  \
# 11806         27.953434        31.714301        25.284095        8.436315
# 11807         27.953434        31.714301        25.284095        8.436315
# 11808         27.953434        31.714301        25.284095        8.436315
# 11809         27.953434        31.714301        25.284095        8.436315
# 11810         27.953434        31.714301        25.284095        8.436315
#
#        windspeed_max        Date   Epiweek    Town Region
# 11806       32.78382   4/10/2020  2020-W41  yishun  North
# 11807       32.78382  11/10/2020  2020-W42  yishun  North
# 11808       32.78382  18/10/2020  2020-W43  yishun  North
# 11809       32.78382  25/10/2020  2020-W44  yishun  North
# 11810       32.78382   1/11/2020  2020-W45  yishun  North

# %%
df3 = df2.merge(freq_gtrends, left_on = 'Date', right_on = 'date_new', how ='left')

# %%
df3.isnull().sum()
# Out:
# epi_week_year               0
# start                       0
# dengue_cases                0
# Station                     0
# Year                        0
# Month                       0
# Day                         0
# total_rainfall              0
# rainfall_30min              0
# rainfall_60min              0
# rainfall_120min             0
# temperature_mean            0
# temperature_max             0
# temperature_min             0
# windspeed_mean              0
# windspeed_max               0
# Date                        0
# Epiweek                     0
# Town                        0
# Region                      0
# date                      918
# freq_dengue_gtrends         0
# year                      918
# freq_wolbachia_gtrends    918
# date_new                  918
# dtype: int64

# %% [markdown]
# Finally, impute then null values for `freq_dengue_gtrends` and `freq_wolbachia_gtrends` with global means.
# Drop the columns `Year`,`Month`,`Day`,`Station` (this is a repeat of Town column).

# %%
df3['freq_dengue_gtrends'] = df3['freq_dengue_gtrends'].fillna(df3['freq_dengue_gtrends'].mean())

# %%
df3['freq_wolbachia_gtrends'] = df3['freq_wolbachia_gtrends'].fillna(df3['freq_wolbachia_gtrends'].mean())

# %%
df3.isnull().sum()
# Out:
# epi_week_year               0
# start                       0
# dengue_cases                0
# Station                     0
# Year                        0
# Month                       0
# Day                         0
# total_rainfall              0
# rainfall_30min              0
# rainfall_60min              0
# rainfall_120min             0
# temperature_mean            0
# temperature_max             0
# temperature_min             0
# windspeed_mean              0
# windspeed_max               0
# Date                        0
# Epiweek                     0
# Town                        0
# Region                      0
# date                      918
# freq_dengue_gtrends         0
# year                      918
# freq_wolbachia_gtrends    918
# date_new                  918
# dtype: int64

# %%
df3.drop(columns = ['Year','Month','Day','Station','date', 'year','date_new'], inplace = True)

# %%
df3.isnull().sum()
# Out:
# epi_week_year             0
# start                     0
# dengue_cases              0
# total_rainfall            0
# rainfall_30min            0
# rainfall_60min            0
# rainfall_120min           0
# temperature_mean          0
# temperature_max           0
# temperature_min           0
# windspeed_mean            0
# windspeed_max             0
# Date                      0
# Epiweek                   0
# Town                      0
# Region                    0
# freq_dengue_gtrends       0
# freq_wolbachia_gtrends    0
# dtype: int64

# %%
df3.shape
# Out:
# (9494, 18)

# %%
df3.to_excel('Output after Merged.xlsx', index=False)

# %% [markdown]
# ### Add in Project Wolbachia trends
# Based in what we know online about the Project Wolbachia neighbourhoods they were conducted and years

# %% [markdown]
# ### Quick correlations

# %% [markdown]
# If there is time, we will do some EDA on this dataset and the individual datasets.
#
# In the next workbook, we shall fit the following models for a) whole of Singapore and b) individual regions.
#
# Our problem is a regression problem to predict number of dengue cases, not a classification problem, so we will go with common regressors we have learnt before such as
# - SVM
# - etc
# - etc
